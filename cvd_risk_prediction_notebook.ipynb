# %% [markdown]
# # Importing dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import recall_score, accuracy_score, classification_report
from sklearn.model_selection import cross_val_score
from imblearn.pipeline import Pipeline, make_pipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import TomekLinks
import pickle
from IPython.display import Markdown, display
from sklearn import preprocessing
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
    auc,
    confusion_matrix,
)

# %% [markdown]
# # Creating functions

# %%
## printing the shape and head
def head(df,shape_only=False):
    print(df.shape)

    if shape_only:
        return
    else:
        return df.head()

## for EDA of categorical values
def eda_bivariate_categorical(df,column,target):

    fig,ax = plt.subplots(figsize = (9,8))

    color = 'Set2'

    palette_color = sns.color_palette(color)

    ax = sns.countplot(x = column, data=df, hue=target,palette=color,order = df[column].value_counts().index)
    ax.set_ylabel('Count')

    offset = df[column].value_counts().max() * 0.005

    list_bars = df.groupby([column,target])[column].agg(['count']).unstack().fillna(0).values

    patches = ax.patches
    bars_pos = 0

    for i in range(df[target].nunique()):
        for j in range(df[column].nunique()):
            list_bars_col = list_bars[j]
            total_sum = list_bars_col.sum()
            value = list_bars_col[i]

            percentage = value / total_sum

            if percentage == 0:
                bars_pos += 1
                continue
            else:
                x = patches[bars_pos].get_x() + patches[j].get_width()/2
                y = patches[bars_pos].get_height() + offset
                ax.annotate('{:.1f}%'.format(percentage*100), (x, y), ha='center')
                bars_pos += 1
    plt.show()

## Function that plots numerical variables into histogram and violin plot
def eda_bivariate_numerical(data,column,target,color,
                    figsize=(12,6),
                    # save=True,
                    val=0,
                    target_type = 'Numerical'):

    fig, axes = plt.subplots(1, 2, figsize=figsize)
    cmap = sns.color_palette(color)
    val = val

    for i in range(1):
        for j in range(2):
            if j==0:
                    sns.histplot(data = data,x=data[column],hue=target,
                                bins=50,kde=True,palette=color,ax=axes[j])
                    axes[j].set(xlabel=None)
                    axes[j].grid(False)
            elif j==1:
                sns.boxplot(data = data,x=data[column],y = target, ax=axes[j], palette=color,orient='h',
                )
                axes[j].set(xlabel=None)
                axes[j].grid(False)
                val += 1
                plt.tight_layout()
            if target_type == 'Numerical':
                plt.suptitle(column)
            else:
                plt.suptitle(f'{column} vs. {target}')
    plt.show()

    # path = 'Figures\\Numerical\\'
    # if save:
    #     plt.savefig(f"{path}{column}.pdf",dpi=1000)


## print text to see the font
def print_text(text):
    fig, ax = plt.subplots(figsize=(6, 1), facecolor="#eefade")
    ax.text(0.5, 0.5, text, ha='center', va='center', size=40)
    ax.axis("off")
    plt.show()

# %% [markdown]
# # Reading dataset and showing its descriptions

# %%
df = pd.read_csv('./CVD_cleaned.csv')

## Viewing the dataframe and shape
head(df,shape_only=False)
# Out:
# (308854, 19)
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# 0           No         No       No       Yes  Female        70-74
# 1           No         No      Yes        No  Female        70-74
# 2           No         No      Yes        No  Female        60-64
# 3           No         No      Yes        No    Male        75-79
# 4           No         No       No        No    Male          80+
#
#    Height_(cm)  Weight_(kg)    BMI Smoking_History  Alcohol_Consumption  \
# 0        150.0        32.66  14.54             Yes                  0.0
# 1        165.0        77.11  28.29              No                  0.0
# 2        163.0        88.45  33.47              No                  4.0
# 3        180.0        93.44  28.73              No                  0.0
# 4        191.0        88.45  24.37             Yes                  0.0
#
#    Fruit_Consumption  Green_Vegetables_Consumption  FriedPotato_Consumption
# 0               30.0                          16.0                     12.0
# 1               30.0                           0.0                      4.0
# 2               12.0                           3.0                     16.0
# 3               30.0                          30.0                      8.0
# 4                8.0                           4.0                      0.0

# %%
## Setting the target variable
target = 'Heart_Disease'

# %%
## Creating numerical and categorical columns
numerical = df.select_dtypes(include=['float64']).columns.sort_values()
categorical = df.select_dtypes(include=['object']).columns.sort_values()

## Printing the length of numerical and categorical. The total length should have
## the same length as our dataframe
print(f'There are {len(categorical)} Categorical variables')
print(f'There are {len(numerical)} Numerical variables')
# Out:
# There are 12 Categorical variables
# There are 7 Numerical variables

# %%
## Showing the columns in alphabetical order
df.columns.sort_values()

## Showing the descriptions of numerical variables
print('')
num_describe = df.describe().T
num_describe_table = num_describe.loc[:,['mean', 'std', '25%', '50%', '75%']]
print(num_describe_table)

## Showing the descriptions of categorical variables
print('')
object_describe_table = df.describe(include=object)
print(object_describe_table)
## print it to latex
# print(object_describe_table.to_latex())
# Out:
#                                     mean        std     25%     50%     75%
# Height_(cm)                   170.615249  10.658026  163.00  170.00  178.00
# Weight_(kg)                    83.588655  21.343210   68.04   81.65   95.25
# BMI                            28.626211   6.522323   24.21   27.44   31.85
# Alcohol_Consumption             5.096366   8.199763    0.00    1.00    6.00
# Fruit_Consumption              29.835200  24.875735   12.00   30.00   30.00
# Green_Vegetables_Consumption   15.110441  14.926238    4.00   12.00   20.00
# FriedPotato_Consumption         6.296616   8.582954    2.00    4.00    8.00
#
#        General_Health               Checkup Exercise Heart_Disease  \
# count          308854                308854   308854        308854
# unique              5                     5        2             2
# top         Very Good  Within the past year      Yes            No
# freq           110395                239371   239381        283883
#
#        Skin_Cancer Other_Cancer Depression Diabetes Arthritis     Sex  \
# count       308854       308854     308854   308854    308854  308854
# unique           2            2          2        4         2       2
# top             No           No         No       No        No  Female
# freq        278860       278976     246953   259141    207783  160196
#
#        Age_Category Smoking_History
# count        308854          308854
# unique           13               2
# top           65-69              No
# freq          33434          183590

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ## Target Variable
#
# ### Categorical

# %%
fig, ax = plt.subplots(figsize=(9, 8))

# Assign 'x' variable to 'hue' and set 'legend' to 'False'
ax = sns.countplot(x=target,
                   data=df,
                   hue=target,  # Assign 'x' variable to 'hue'
                   palette='Set2',
                   order=df[target].value_counts().index,
                   legend=False  # Set legend to False
                   )

sns.set(font='Arial')


ax.set_ylabel('Count')

patches = ax.patches

for j in range(len(patches)):
    percentage = list(df[target].value_counts())[j] / df[target].value_counts().sum()
    offset = df[target].value_counts().max() * 0.01
    x = patches[j].get_x() + patches[j].get_width() / 2
    y = patches[j].get_height() + offset
    ax.annotate('{:.1f}%'.format(percentage * 100), (x, y), ha='center')

plt.show()

# %% [markdown]
# - We can deduct from this that the target variable is imbalanced.

# %% [markdown]
# ### Univariate Analysis

# %%
sns.set(font_scale=0.5)

for i in df.columns:
    if i == target:
        continue

    if i in categorical:
        if df[i].nunique() > 15:
            print(f'column {i} has many unique values n = {df[i].nunique()} and will not be plotted')
            print('=======================================================')
            continue
        else:
            print(f'{i}')
            fig, ax = plt.subplots(figsize=(9, 8))
            color = 'Set2'
            palette_color = sns.color_palette(color)
            
            # Assign 'x' variable to 'hue' and set 'legend' to 'False'
            ax = sns.countplot(x=i,
                data=df,
                hue=i,  # Assign 'x' variable to 'hue'
                palette=color,
                order=df[i].value_counts().index,
                legend=False  # Set legend to False
            )
            ax.set_ylabel('Count')

            patches = ax.patches

            for j in range(len(patches)):
                offset = df[i].value_counts().max() * 0.01
                percentage = list(df[i].value_counts())[j] / df[i].value_counts().sum()
                x = patches[j].get_x() + patches[j].get_width() / 2
                y = patches[j].get_height() + offset
                ax.annotate('{:.1f}%'.format(percentage * 100), (x, y), ha='center')

            plt.show()
            print('=======================================================')

    elif i in numerical:
        print(f'{i}')
        fig, ax = plt.subplots(figsize=(9, 8))
        color = 'Set2'
        palette_color = sns.color_palette(color)
        ax = sns.histplot(x=i,
            data=df,
            kde=True,
            color=palette_color[0],
        )
        ax.set_ylabel('Count')
        plt.show()
        print('=======================================================')
# Out:
# General_Health
# =======================================================
# Checkup
# =======================================================
# Exercise
# =======================================================
# Skin_Cancer
# =======================================================
# Other_Cancer
# =======================================================
# Depression
# =======================================================
# Diabetes
# =======================================================
# Arthritis
# =======================================================
# Sex
# =======================================================
# Age_Category
# =======================================================
# Height_(cm)
# =======================================================
# Weight_(kg)
# =======================================================
# BMI
# =======================================================
# Smoking_History
# =======================================================
# Alcohol_Consumption
# =======================================================
# Fruit_Consumption
# =======================================================
# Green_Vegetables_Consumption
# =======================================================
# FriedPotato_Consumption
# =======================================================

# %% [markdown]
# ### Bivariate Analysis for Classification

# %% [markdown]
# #### Categorical

# %%
for i in categorical:
        if i == target:
            continue

        if df[i].nunique() > 15:
            print(f'column {i} has many unique values n = {df[i].nunique()} and will not be plotted')
            print('=======================================================')
            continue

        if i in df.columns:
            print(f'{i} vs. {target}')
            eda_bivariate_categorical(df,i,target)
            print('=======================================================')
# Out:
# Age_Category vs. Heart_Disease
# =======================================================
# Arthritis vs. Heart_Disease
# =======================================================
# Checkup vs. Heart_Disease
# =======================================================
# Depression vs. Heart_Disease
# =======================================================
# Diabetes vs. Heart_Disease
# =======================================================
# Exercise vs. Heart_Disease
# =======================================================
# General_Health vs. Heart_Disease
# =======================================================
# Other_Cancer vs. Heart_Disease
# =======================================================
# Sex vs. Heart_Disease
# =======================================================
# Skin_Cancer vs. Heart_Disease
# =======================================================
# Smoking_History vs. Heart_Disease
# =======================================================

# %% [markdown]
# #### Multivariate Analysis

# %%
## Plotting the correlation matrix
correlation_matrix = df[numerical].corr()
plt.figure(figsize=(9,8))

sns.set(font_scale=1)

## use mask to cover the upper diagonal in the matrix
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

sns.heatmap(correlation_matrix,
            cmap='RdBu_r',
            # cmap='RdYlGn',
            annot=True,
            # Masking the diagonal
            # mask=mask,
            fmt='.2f',
            vmin=-1, vmax=1)

plt.show()

# %% [markdown]
# # Feature Engineering (Preprocessing)

# %% [markdown]
# Changing the values of Heart Disease to 0 and 1 for preprocessing steps

# %%
df['Heart_Disease'] = df['Heart_Disease'].map({'No':0,'Yes':1})
print('')
print(df['Heart_Disease'].value_counts())
# Out:
# Heart_Disease
# 0    283883
# 1     24971
# Name: count, dtype: int64

# %% [markdown]
# Splitting the train and test set. Using stratify to keep the ratio between two classes be the same

# %%
from sklearn.model_selection import train_test_split

train,test = train_test_split(df, test_size=0.2,random_state=22,stratify=df['Heart_Disease'])

print(train.shape)
print(test.shape)
# Out:
# (247083, 19)
# (61771, 19)

# %% [markdown]
# Showing the ratio of the target variable from train and test set

# %%
yes = train['Heart_Disease'].value_counts()[0]/len(train['Heart_Disease'])*100
no = train['Heart_Disease'].value_counts()[1]/len(train['Heart_Disease'])*100
print('Train Set')
print(f'ratio of people with heart disease to total is {yes}')
print(f'ratio of people that dont have heart disease to total is {no}')
print('')

yes = test['Heart_Disease'].value_counts()[0]/len(test['Heart_Disease'])*100
no = test['Heart_Disease'].value_counts()[1]/len(test['Heart_Disease'])*100
print('Test Set')
print(f'ratio of people with heart disease to total is {yes}')
print(f'ratio of people that dont have heart disease to total is {no}')
# Out:
# Train Set
# ratio of people with heart disease to total is 91.91486261701533
# ratio of people that dont have heart disease to total is 8.085137382984666
#
# Test Set
# ratio of people with heart disease to total is 91.91530005989866
# ratio of people that dont have heart disease to total is 8.084699940101341

# %%
## Splitting the X and y variables in the train set
X_train = train.drop("Heart_Disease", axis=1)
y_train = train["Heart_Disease"].copy()

## Splitting the X and y variables in the test set
X_test = test.drop("Heart_Disease", axis=1)
y_test = test["Heart_Disease"].copy()

# %% [markdown]
# Printing the number of unique values per each column

# %%
X_train.nunique()
# Out:
# General_Health                     5
# Checkup                            5
# Exercise                           2
# Skin_Cancer                        2
# Other_Cancer                       2
# Depression                         2
# Diabetes                           4
# Arthritis                          2
# Sex                                2
# Age_Category                      13
# Height_(cm)                       98
# Weight_(kg)                      502
# BMI                             3502
# Smoking_History                    2
# Alcohol_Consumption               31
# Fruit_Consumption                 73
# Green_Vegetables_Consumption      73
# FriedPotato_Consumption           67
# dtype: int64

# %% [markdown]
# Notes:
# * There are 8 categorical variables. Variables that are not in order.
# * There are 7 numerical variables.
# * There are 3 ordinal variables. The General Health, Age Category, and the Checkup variable, The data from this can be represented with an order.

# %% [markdown]
# # Creating Pipelines

# %% [markdown]
# ## Categorical Pipeline

# %%
cat_pipeline = make_pipeline(OneHotEncoder(handle_unknown='ignore',drop='first'))

# %% [markdown]
# * For categorical pipeline, only OneHotEncoder will be implemented. Since this dataset has been cleaned and there are no missing values.

# %% [markdown]
# ## Numerical Pipeline

# %%
num_pipeline = make_pipeline(
                             FunctionTransformer(np.log1p,feature_names_out='one-to-one'),
                             StandardScaler()
                            )

# %% [markdown]
# For numerical pipeline, two methods are used:
# 1. Log Transform: From the EDA, most of the numerical functions are skewed right.
# 2. Standard Scaler: The numerical variable will be scaled to put them all on the same scale.

# %% [markdown]
# ## Ordinal Pipeline

# %%
## Age Category Pipeline
agecat_pipeline = make_pipeline(
        OrdinalEncoder()
)

## General Health Pipeline
genhealth_pipeline = make_pipeline(
        OrdinalEncoder(categories=[['Poor','Fair','Good','Very Good','Excellent']])
)

## Checkup Pipeline
checkup_pipeline = make_pipeline(
        OrdinalEncoder(categories=[['Within the past year','Within the past 2 years','Within the past 5 years','5 or more years ago','Never']])
)

# %% [markdown]
# * For the ordinal variable, the variables are transformed based on their order. The values with in the lowest order will start with 0 and increases by 1.

# %% [markdown]
# ## Creating the pipeline lists

# %%
## Setting each column to the pipeline where they will be used
num_pipe_col = numerical

cat_pipe_col = ['Arthritis', 'Depression', 'Diabetes',
       'Exercise', 'Other_Cancer', 'Sex',
       'Skin_Cancer', 'Smoking_History']

# %% [markdown]
# ## Finalizing the preprocessing pipeline

# %%
## Combining all the pipelines and creating a main pipeline to enter all the data
preprocessing = ColumnTransformer([
    ('Categorical', cat_pipeline,   cat_pipe_col),
    ('Age_Category',agecat_pipeline,['Age_Category']),
    ('Checkup',checkup_pipeline,['Checkup']),
    ('Gen_health',genhealth_pipeline,['General_Health']),
    ('Numerical',   num_pipeline,  num_pipe_col),
],remainder='passthrough')
preprocessing
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('Categorical',
#                                  Pipeline(steps=[('onehotencoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'))]),
#                                  ['Arthritis', 'Depression', 'Diabetes',
#                                   'Exercise', 'Other_Cancer', 'Sex',
#                                   'Skin_Cancer', 'Smoking_History']),
#                                 ('Age_Category',
#                                  Pipeline(steps=[('ordinalencoder',
#                                                   OrdinalEncoder())]),
#                                  ['Age_Category']),...
#                                                                               'Excellent']]))]),
#                                  ['General_Health']),
#                                 ('Numerical',
#                                  Pipeline(steps=[('functiontransformer',
#                                                   FunctionTransformer(feature_names_out='one-to-one',
#                                                                       func=<ufunc 'log1p'>)),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  Index(['Alcohol_Consumption', 'BMI', 'FriedPotato_Consumption',
#        'Fruit_Consumption', 'Green_Vegetables_Consumption', 'Height_(cm)',
#        'Weight_(kg)'],
#       dtype='object'))])

# %%
## Using preprocessing pipeline
print('Shape before the preprocessing:')
print(X_train.shape)

train_preprocessed = preprocessing.fit_transform(X_train)

print('Shape after the preprocessing:')
print(train_preprocessed.shape)
# Out:
# Shape before the preprocessing:
# (247083, 18)
# Shape after the preprocessing:
# (247083, 20)

# %%
train_preprocessed[:5]
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  7.00000000e+00,  0.00000000e+00,
#          4.00000000e+00,  1.87007552e+00, -1.52461967e+00,
#         -4.87091678e-01,  6.13004916e-03, -9.53748411e-01,
#         -2.13824879e-01, -1.45449652e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  1.20000000e+01,  0.00000000e+00,
#          3.00000000e+00, -9.10705045e-01, -7.75562687e-01,
#         -1.66354705e+00, -2.04183373e-01, -7.34162436e-01,
#          8.86072283e-01, -2.05255774e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  9.00000000e+00,  0.00000000e+00,
#          4.00000000e+00, -9.10705045e-01, -2.32812829e-01,
#          1.08314391e+00, -4.71183320e-01,  4.70102354e-01,
#         -2.13824879e-01, -3.26905335e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.20000000e+01,  0.00000000e+00,
#          2.00000000e+00, -3.19104954e-01, -7.91320307e-01,
#          1.37041597e+00,  3.93759689e-01, -1.23684397e+00,
#          4.36914626e-01, -4.52251923e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  2.00000000e+00,  0.00000000e+00,
#          2.00000000e+00, -3.19104954e-01,  9.17525627e-01,
#          6.89363691e-01,  3.93759689e-01,  2.06115298e-01,
#         -1.49722004e+00,  2.77819650e-02]])

# %% [markdown]
# # Feature Selection (Recursive Feature Elimination)

# %% [markdown]
# ## Define the RFE Model

# %%
# Define the RFE model with a classifier (e.g., RandomForestClassifier)
rfe_model = RFE(estimator=RandomForestClassifier(), n_features_to_select=5)

# %% [markdown]
# ## Fit the RFE Model to the Training Data

# %%
# Fit the RFE model to your training data
X_train_rfe = rfe_model.fit_transform(train_preprocessed, y_train)

# %% [markdown]
# ## Print the Ranking of Features Based on Importance

# %%
# Print the ranking of features based on importance
print("Feature Rankings:")
for feature, rank in zip(X_train.columns, rfe_model.ranking_):
    print(f"Feature: {feature}, Rank: {rank}")
# Out:
# Feature Rankings:
# Feature: General_Health, Rank: 7
# Feature: Checkup, Rank: 8
# Feature: Exercise, Rank: 15
# Feature: Skin_Cancer, Rank: 6
# Feature: Other_Cancer, Rank: 16
# Feature: Depression, Rank: 9
# Feature: Diabetes, Rank: 11
# Feature: Arthritis, Rank: 14
# Feature: Sex, Rank: 13
# Feature: Age_Category, Rank: 12
# Feature: Height_(cm), Rank: 2
# Feature: Weight_(kg), Rank: 10
# Feature: BMI, Rank: 4
# Feature: Smoking_History, Rank: 5
# Feature: Alcohol_Consumption, Rank: 1
# Feature: Fruit_Consumption, Rank: 1
# Feature: Green_Vegetables_Consumption, Rank: 1
# Feature: FriedPotato_Consumption, Rank: 1

# %% [markdown]
# ## Print the List of Selected Features

# %%
# Print the list of selected features
selected_features = pd.DataFrame(train_preprocessed).columns[rfe_model.support_]
print("Selected Features:")
print(selected_features)
# Out:
# Selected Features:
# Index([14, 15, 16, 17, 19], dtype='int64')

# %% [markdown]
# # Model Development

# %% [markdown]
# ## Defining the MLP Model

# %%
mlp_model_rfe = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=1, warm_start=True, random_state=42)

# %% [markdown]
# ## Define the number of iterations

# %%
# Define the number of iterations
max_iterations = 5000

# %% [markdown]
# ## Initialise Lists to Store Evaluation Metrics After Each Iteration

# %%
# Initialize lists to store evaluation metrics after each iteration
accuracy_scores = []
precision_scores = []
recall_scores = []
roc_auc_scores = []
confusion_matrices = []

# %% [markdown]
# ## Plot/Output Training Progress

# %%
for iteration in range(max_iterations):
    mlp_model_rfe.partial_fit(train_preprocessed, y_train, classes=np.unique(y_train))

    # After each iteration, evaluate the model
    y_pred = mlp_model_rfe.predict(train_preprocessed)

    # Compute evaluation metrics
    accuracy = accuracy_score(y_train, y_pred)
    precision = precision_score(y_train, y_pred)
    recall = recall_score(y_train, y_pred)
    fpr, tpr, _ = roc_curve(y_train, y_pred)
    auc_roc = auc(fpr, tpr)
    confusion = confusion_matrix(y_train, y_pred)

    # Append metrics to the respective lists
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    roc_auc_scores.append(auc_roc)
    confusion_matrices.append(confusion)

    print(f'Iteration {iteration + 1}/{max_iterations} - Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, AUC ROC: {auc_roc:.4f}')
# Out:
# Iteration 1/5000 - Accuracy: 0.9195, Precision: 0.5622, Recall: 0.0183, AUC ROC: 0.5085
# Iteration 2/5000 - Accuracy: 0.9195, Precision: 0.5845, Recall: 0.0166, AUC ROC: 0.5078
# Iteration 3/5000 - Accuracy: 0.9196, Precision: 0.5795, Recall: 0.0212, AUC ROC: 0.5099
# Iteration 4/5000 - Accuracy: 0.9196, Precision: 0.5793, Recall: 0.0201, AUC ROC: 0.5094
# Iteration 5/5000 - Accuracy: 0.9196, Precision: 0.5832, Recall: 0.0184, AUC ROC: 0.5086
# Iteration 6/5000 - Accuracy: 0.9196, Precision: 0.5897, Recall: 0.0196, AUC ROC: 0.5092
# Iteration 7/5000 - Accuracy: 0.9196, Precision: 0.5841, Recall: 0.0202, AUC ROC: 0.5095
# Iteration 8/5000 - Accuracy: 0.9196, Precision: 0.5879, Recall: 0.0199, AUC ROC: 0.5093
# Iteration 9/5000 - Accuracy: 0.9197, Precision: 0.5857, Recall: 0.0226, AUC ROC: 0.5106
# Iteration 10/5000 - Accuracy: 0.9197, Precision: 0.5833, Recall: 0.0228, AUC ROC: 0.5107
# Iteration 11/5000 - Accuracy: 0.9197, Precision: 0.5859, Recall: 0.0241, AUC ROC: 0.5113
# Iteration 12/5000 - Accuracy: 0.9197, Precision: 0.5849, Recall: 0.0252, AUC ROC: 0.5118
# Iteration 13/5000 - Accuracy: 0.9197, Precision: 0.5783, Recall: 0.0259, AUC ROC: 0.5121
# Iteration 14/5000 - Accuracy: 0.9198, Precision: 0.5789, Recall: 0.0288, AUC ROC: 0.5135
# Iteration 15/5000 - Accuracy: 0.9199, Precision: 0.5893, Recall: 0.0309, AUC ROC: 0.5145
# Iteration 16/5000 - Accuracy: 0.9199, Precision: 0.5883, Recall: 0.0308, AUC ROC: 0.5145
# Iteration 17/5000 - Accuracy: 0.9199, Precision: 0.5880, Recall: 0.0319, AUC ROC: 0.5150
# Iteration 18/5000 - Accuracy: 0.9199, Precision: 0.5885, Recall: 0.0328, AUC ROC: 0.5154
# Iteration 19/5000 - Accuracy: 0.9199, Precision: 0.5761, Recall: 0.0352, AUC ROC: 0.5165
# Iteration 20/5000 - Accuracy: 0.9200, Precision: 0.5868, Recall: 0.0338, AUC ROC: 0.5159
# Iteration 21/5000 - Accuracy: 0.9199, Precision: 0.5797, Recall: 0.0331, AUC ROC: 0.5155
# Iteration 22/5000 - Accuracy: 0.9199, Precision: 0.5677, Recall: 0.0367, AUC ROC: 0.5171
# Iteration 23/5000 - Accuracy: 0.9199, Precision: 0.5690, Recall: 0.0388, AUC ROC: 0.5181
# Iteration 24/5000 - Accuracy: 0.9199, Precision: 0.5653, Recall: 0.0398, AUC ROC: 0.5186
# Iteration 25/5000 - Accuracy: 0.9199, Precision: 0.5681, Recall: 0.0403, AUC ROC: 0.5188
# Iteration 26/5000 - Accuracy: 0.9200, Precision: 0.5788, Recall: 0.0393, AUC ROC: 0.5184
# Iteration 27/5000 - Accuracy: 0.9200, Precision: 0.5734, Recall: 0.0393, AUC ROC: 0.5184
# Iteration 28/5000 - Accuracy: 0.9200, Precision: 0.5751, Recall: 0.0400, AUC ROC: 0.5187
# Iteration 29/5000 - Accuracy: 0.9200, Precision: 0.5679, Recall: 0.0436, AUC ROC: 0.5203
# Iteration 30/5000 - Accuracy: 0.9201, Precision: 0.5756, Recall: 0.0437, AUC ROC: 0.5204
# Iteration 31/5000 - Accuracy: 0.9202, Precision: 0.5868, Recall: 0.0428, AUC ROC: 0.5201
# Iteration 32/5000 - Accuracy: 0.9201, Precision: 0.5809, Recall: 0.0431, AUC ROC: 0.5202
# Iteration 33/5000 - Accuracy: 0.9201, Precision: 0.5717, Recall: 0.0459, AUC ROC: 0.5214
# Iteration 34/5000 - Accuracy: 0.9200, Precision: 0.5703, Recall: 0.0428, AUC ROC: 0.5200
# Iteration 35/5000 - Accuracy: 0.9201, Precision: 0.5727, Recall: 0.0442, AUC ROC: 0.5206
# Iteration 36/5000 - Accuracy: 0.9200, Precision: 0.5701, Recall: 0.0436, AUC ROC: 0.5203
# Iteration 37/5000 - Accuracy: 0.9201, Precision: 0.5746, Recall: 0.0465, AUC ROC: 0.5217
# Iteration 38/5000 - Accuracy: 0.9200, Precision: 0.5725, Recall: 0.0439, AUC ROC: 0.5205
# Iteration 39/5000 - Accuracy: 0.9201, Precision: 0.5746, Recall: 0.0449, AUC ROC: 0.5210
# Iteration 40/5000 - Accuracy: 0.9201, Precision: 0.5737, Recall: 0.0478, AUC ROC: 0.5223
# Iteration 41/5000 - Accuracy: 0.9201, Precision: 0.5665, Recall: 0.0482, AUC ROC: 0.5225
# Iteration 42/5000 - Accuracy: 0.9203, Precision: 0.5807, Recall: 0.0494, AUC ROC: 0.5231
# Iteration 43/5000 - Accuracy: 0.9203, Precision: 0.5857, Recall: 0.0476, AUC ROC: 0.5223
# Iteration 44/5000 - Accuracy: 0.9203, Precision: 0.5823, Recall: 0.0498, AUC ROC: 0.5233
# Iteration 45/5000 - Accuracy: 0.9202, Precision: 0.5787, Recall: 0.0477, AUC ROC: 0.5223
# Iteration 46/5000 - Accuracy: 0.9203, Precision: 0.5849, Recall: 0.0507, AUC ROC: 0.5238
# Iteration 47/5000 - Accuracy: 0.9204, Precision: 0.5870, Recall: 0.0507, AUC ROC: 0.5238
# Iteration 48/5000 - Accuracy: 0.9204, Precision: 0.5857, Recall: 0.0522, AUC ROC: 0.5245
# Iteration 49/5000 - Accuracy: 0.9203, Precision: 0.5827, Recall: 0.0510, AUC ROC: 0.5239
# Iteration 50/5000 - Accuracy: 0.9204, Precision: 0.5861, Recall: 0.0518, AUC ROC: 0.5243
# Iteration 51/5000 - Accuracy: 0.9204, Precision: 0.5898, Recall: 0.0510, AUC ROC: 0.5239
# Iteration 52/5000 - Accuracy: 0.9204, Precision: 0.5910, Recall: 0.0515, AUC ROC: 0.5242
# Iteration 53/5000 - Accuracy: 0.9204, Precision: 0.5877, Recall: 0.0520, AUC ROC: 0.5244
# Iteration 54/5000 - Accuracy: 0.9204, Precision: 0.5864, Recall: 0.0530, AUC ROC: 0.5249
# Iteration 55/5000 - Accuracy: 0.9204, Precision: 0.5848, Recall: 0.0528, AUC ROC: 0.5248
# Iteration 56/5000 - Accuracy: 0.9204, Precision: 0.5843, Recall: 0.0554, AUC ROC: 0.5259
# Iteration 57/5000 - Accuracy: 0.9205, Precision: 0.5905, Recall: 0.0541, AUC ROC: 0.5254
# Iteration 58/5000 - Accuracy: 0.9204, Precision: 0.5836, Recall: 0.0547, AUC ROC: 0.5256
# Iteration 59/5000 - Accuracy: 0.9205, Precision: 0.5883, Recall: 0.0542, AUC ROC: 0.5254
# Iteration 60/5000 - Accuracy: 0.9205, Precision: 0.5895, Recall: 0.0551, AUC ROC: 0.5258
# Iteration 61/5000 - Accuracy: 0.9204, Precision: 0.5806, Recall: 0.0559, AUC ROC: 0.5262
# Iteration 62/5000 - Accuracy: 0.9204, Precision: 0.5845, Recall: 0.0535, AUC ROC: 0.5251
# Iteration 63/5000 - Accuracy: 0.9204, Precision: 0.5815, Recall: 0.0559, AUC ROC: 0.5262
# Iteration 64/5000 - Accuracy: 0.9204, Precision: 0.5855, Recall: 0.0540, AUC ROC: 0.5253
# Iteration 65/5000 - Accuracy: 0.9205, Precision: 0.5886, Recall: 0.0544, AUC ROC: 0.5255
# Iteration 66/5000 - Accuracy: 0.9205, Precision: 0.5912, Recall: 0.0557, AUC ROC: 0.5261
# Iteration 67/5000 - Accuracy: 0.9206, Precision: 0.5949, Recall: 0.0577, AUC ROC: 0.5271
# Iteration 68/5000 - Accuracy: 0.9206, Precision: 0.5906, Recall: 0.0586, AUC ROC: 0.5275
# Iteration 69/5000 - Accuracy: 0.9207, Precision: 0.5931, Recall: 0.0595, AUC ROC: 0.5279
# Iteration 70/5000 - Accuracy: 0.9207, Precision: 0.5968, Recall: 0.0596, AUC ROC: 0.5280
# Iteration 71/5000 - Accuracy: 0.9207, Precision: 0.5970, Recall: 0.0604, AUC ROC: 0.5284
# Iteration 72/5000 - Accuracy: 0.9207, Precision: 0.5972, Recall: 0.0604, AUC ROC: 0.5284
# Iteration 73/5000 - Accuracy: 0.9208, Precision: 0.5937, Recall: 0.0630, AUC ROC: 0.5296
# Iteration 74/5000 - Accuracy: 0.9207, Precision: 0.5903, Recall: 0.0618, AUC ROC: 0.5290
# Iteration 75/5000 - Accuracy: 0.9207, Precision: 0.5913, Recall: 0.0629, AUC ROC: 0.5295
# Iteration 76/5000 - Accuracy: 0.9208, Precision: 0.6014, Recall: 0.0603, AUC ROC: 0.5284
# Iteration 77/5000 - Accuracy: 0.9207, Precision: 0.5979, Recall: 0.0602, AUC ROC: 0.5283
# Iteration 78/5000 - Accuracy: 0.9208, Precision: 0.5994, Recall: 0.0607, AUC ROC: 0.5286
# Iteration 79/5000 - Accuracy: 0.9209, Precision: 0.6119, Recall: 0.0602, AUC ROC: 0.5284
# Iteration 80/5000 - Accuracy: 0.9208, Precision: 0.6042, Recall: 0.0601, AUC ROC: 0.5283
# Iteration 81/5000 - Accuracy: 0.9209, Precision: 0.6044, Recall: 0.0614, AUC ROC: 0.5289
# Iteration 82/5000 - Accuracy: 0.9209, Precision: 0.6060, Recall: 0.0611, AUC ROC: 0.5288
# Iteration 83/5000 - Accuracy: 0.9209, Precision: 0.6080, Recall: 0.0603, AUC ROC: 0.5284
# Iteration 84/5000 - Accuracy: 0.9209, Precision: 0.6120, Recall: 0.0606, AUC ROC: 0.5286
# Iteration 85/5000 - Accuracy: 0.9209, Precision: 0.6068, Recall: 0.0609, AUC ROC: 0.5287
# Iteration 86/5000 - Accuracy: 0.9210, Precision: 0.6127, Recall: 0.0615, AUC ROC: 0.5290
# Iteration 87/5000 - Accuracy: 0.9210, Precision: 0.6077, Recall: 0.0645, AUC ROC: 0.5304
# Iteration 88/5000 - Accuracy: 0.9209, Precision: 0.6038, Recall: 0.0638, AUC ROC: 0.5300
# Iteration 89/5000 - Accuracy: 0.9209, Precision: 0.6070, Recall: 0.0616, AUC ROC: 0.5291
# Iteration 90/5000 - Accuracy: 0.9210, Precision: 0.6087, Recall: 0.0650, AUC ROC: 0.5307
# Iteration 91/5000 - Accuracy: 0.9211, Precision: 0.6184, Recall: 0.0630, AUC ROC: 0.5298
# Iteration 92/5000 - Accuracy: 0.9209, Precision: 0.6098, Recall: 0.0612, AUC ROC: 0.5289
# Iteration 93/5000 - Accuracy: 0.9211, Precision: 0.6119, Recall: 0.0665, AUC ROC: 0.5314
# Iteration 94/5000 - Accuracy: 0.9211, Precision: 0.6175, Recall: 0.0646, AUC ROC: 0.5305
# Iteration 95/5000 - Accuracy: 0.9212, Precision: 0.6225, Recall: 0.0654, AUC ROC: 0.5309
# Iteration 96/5000 - Accuracy: 0.9212, Precision: 0.6220, Recall: 0.0656, AUC ROC: 0.5310
# Iteration 97/5000 - Accuracy: 0.9211, Precision: 0.6145, Recall: 0.0650, AUC ROC: 0.5307
# Iteration 98/5000 - Accuracy: 0.9212, Precision: 0.6141, Recall: 0.0683, AUC ROC: 0.5323
# Iteration 99/5000 - Accuracy: 0.9212, Precision: 0.6219, Recall: 0.0649, AUC ROC: 0.5307
# Iteration 100/5000 - Accuracy: 0.9211, Precision: 0.6160, Recall: 0.0646, AUC ROC: 0.5305
# Iteration 101/5000 - Accuracy: 0.9211, Precision: 0.6162, Recall: 0.0652, AUC ROC: 0.5308
# Iteration 102/5000 - Accuracy: 0.9212, Precision: 0.6216, Recall: 0.0658, AUC ROC: 0.5311
# Iteration 103/5000 - Accuracy: 0.9212, Precision: 0.6237, Recall: 0.0636, AUC ROC: 0.5301
# Iteration 104/5000 - Accuracy: 0.9212, Precision: 0.6218, Recall: 0.0654, AUC ROC: 0.5310
# Iteration 105/5000 - Accuracy: 0.9213, Precision: 0.6244, Recall: 0.0661, AUC ROC: 0.5313
# Iteration 106/5000 - Accuracy: 0.9212, Precision: 0.6192, Recall: 0.0667, AUC ROC: 0.5315
# Iteration 107/5000 - Accuracy: 0.9213, Precision: 0.6264, Recall: 0.0667, AUC ROC: 0.5316
# Iteration 108/5000 - Accuracy: 0.9213, Precision: 0.6228, Recall: 0.0668, AUC ROC: 0.5316
# Iteration 109/5000 - Accuracy: 0.9212, Precision: 0.6202, Recall: 0.0655, AUC ROC: 0.5310
# Iteration 110/5000 - Accuracy: 0.9213, Precision: 0.6184, Recall: 0.0680, AUC ROC: 0.5321
# Iteration 111/5000 - Accuracy: 0.9213, Precision: 0.6222, Recall: 0.0675, AUC ROC: 0.5320
# Iteration 112/5000 - Accuracy: 0.9213, Precision: 0.6218, Recall: 0.0676, AUC ROC: 0.5320
# Iteration 113/5000 - Accuracy: 0.9213, Precision: 0.6212, Recall: 0.0679, AUC ROC: 0.5321
# Iteration 114/5000 - Accuracy: 0.9214, Precision: 0.6265, Recall: 0.0690, AUC ROC: 0.5327
# Iteration 115/5000 - Accuracy: 0.9213, Precision: 0.6235, Recall: 0.0681, AUC ROC: 0.5323
# Iteration 116/5000 - Accuracy: 0.9214, Precision: 0.6243, Recall: 0.0699, AUC ROC: 0.5331
# Iteration 117/5000 - Accuracy: 0.9214, Precision: 0.6214, Recall: 0.0721, AUC ROC: 0.5341
# Iteration 118/5000 - Accuracy: 0.9214, Precision: 0.6217, Recall: 0.0712, AUC ROC: 0.5337
# Iteration 119/5000 - Accuracy: 0.9214, Precision: 0.6210, Recall: 0.0719, AUC ROC: 0.5340
# Iteration 120/5000 - Accuracy: 0.9216, Precision: 0.6280, Recall: 0.0739, AUC ROC: 0.5350
# Iteration 121/5000 - Accuracy: 0.9216, Precision: 0.6200, Recall: 0.0768, AUC ROC: 0.5363
# Iteration 122/5000 - Accuracy: 0.9215, Precision: 0.6220, Recall: 0.0741, AUC ROC: 0.5351
# Iteration 123/5000 - Accuracy: 0.9215, Precision: 0.6223, Recall: 0.0744, AUC ROC: 0.5352
# Iteration 124/5000 - Accuracy: 0.9216, Precision: 0.6172, Recall: 0.0785, AUC ROC: 0.5371
# Iteration 125/5000 - Accuracy: 0.9216, Precision: 0.6233, Recall: 0.0767, AUC ROC: 0.5363
# Iteration 126/5000 - Accuracy: 0.9216, Precision: 0.6261, Recall: 0.0762, AUC ROC: 0.5361
# Iteration 127/5000 - Accuracy: 0.9216, Precision: 0.6255, Recall: 0.0756, AUC ROC: 0.5358
# Iteration 128/5000 - Accuracy: 0.9214, Precision: 0.6160, Recall: 0.0740, AUC ROC: 0.5350
# Iteration 129/5000 - Accuracy: 0.9216, Precision: 0.6238, Recall: 0.0772, AUC ROC: 0.5365
# Iteration 130/5000 - Accuracy: 0.9215, Precision: 0.6212, Recall: 0.0752, AUC ROC: 0.5356
# Iteration 131/5000 - Accuracy: 0.9215, Precision: 0.6230, Recall: 0.0752, AUC ROC: 0.5356
# Iteration 132/5000 - Accuracy: 0.9216, Precision: 0.6322, Recall: 0.0728, AUC ROC: 0.5345
# Iteration 133/5000 - Accuracy: 0.9215, Precision: 0.6163, Recall: 0.0764, AUC ROC: 0.5361
# Iteration 134/5000 - Accuracy: 0.9215, Precision: 0.6201, Recall: 0.0755, AUC ROC: 0.5357
# Iteration 135/5000 - Accuracy: 0.9215, Precision: 0.6232, Recall: 0.0744, AUC ROC: 0.5352
# Iteration 136/5000 - Accuracy: 0.9216, Precision: 0.6240, Recall: 0.0759, AUC ROC: 0.5360
# Iteration 137/5000 - Accuracy: 0.9216, Precision: 0.6292, Recall: 0.0752, AUC ROC: 0.5356
# Iteration 138/5000 - Accuracy: 0.9216, Precision: 0.6264, Recall: 0.0745, AUC ROC: 0.5353
# Iteration 139/5000 - Accuracy: 0.9216, Precision: 0.6236, Recall: 0.0761, AUC ROC: 0.5360
# Iteration 140/5000 - Accuracy: 0.9215, Precision: 0.6198, Recall: 0.0761, AUC ROC: 0.5360
# Iteration 141/5000 - Accuracy: 0.9215, Precision: 0.6220, Recall: 0.0755, AUC ROC: 0.5357
# Iteration 142/5000 - Accuracy: 0.9216, Precision: 0.6237, Recall: 0.0762, AUC ROC: 0.5361
# Iteration 143/5000 - Accuracy: 0.9216, Precision: 0.6229, Recall: 0.0757, AUC ROC: 0.5359
# Iteration 144/5000 - Accuracy: 0.9215, Precision: 0.6238, Recall: 0.0739, AUC ROC: 0.5350
# Iteration 145/5000 - Accuracy: 0.9215, Precision: 0.6167, Recall: 0.0770, AUC ROC: 0.5364
# Iteration 146/5000 - Accuracy: 0.9217, Precision: 0.6277, Recall: 0.0785, AUC ROC: 0.5372
# Iteration 147/5000 - Accuracy: 0.9217, Precision: 0.6250, Recall: 0.0781, AUC ROC: 0.5370
# Iteration 148/5000 - Accuracy: 0.9216, Precision: 0.6226, Recall: 0.0768, AUC ROC: 0.5363
# Iteration 149/5000 - Accuracy: 0.9216, Precision: 0.6191, Recall: 0.0775, AUC ROC: 0.5367
# Iteration 150/5000 - Accuracy: 0.9217, Precision: 0.6226, Recall: 0.0795, AUC ROC: 0.5377
# Iteration 151/5000 - Accuracy: 0.9216, Precision: 0.6251, Recall: 0.0763, AUC ROC: 0.5361
# Iteration 152/5000 - Accuracy: 0.9216, Precision: 0.6220, Recall: 0.0774, AUC ROC: 0.5367
# Iteration 153/5000 - Accuracy: 0.9216, Precision: 0.6197, Recall: 0.0794, AUC ROC: 0.5376
# Iteration 154/5000 - Accuracy: 0.9216, Precision: 0.6225, Recall: 0.0780, AUC ROC: 0.5369
# Iteration 155/5000 - Accuracy: 0.9217, Precision: 0.6220, Recall: 0.0796, AUC ROC: 0.5377
# Iteration 156/5000 - Accuracy: 0.9217, Precision: 0.6239, Recall: 0.0788, AUC ROC: 0.5373
# Iteration 157/5000 - Accuracy: 0.9217, Precision: 0.6287, Recall: 0.0769, AUC ROC: 0.5364
# Iteration 158/5000 - Accuracy: 0.9218, Precision: 0.6330, Recall: 0.0787, AUC ROC: 0.5374
# Iteration 159/5000 - Accuracy: 0.9216, Precision: 0.6226, Recall: 0.0775, AUC ROC: 0.5367
# Iteration 160/5000 - Accuracy: 0.9217, Precision: 0.6303, Recall: 0.0776, AUC ROC: 0.5368
# Iteration 161/5000 - Accuracy: 0.9217, Precision: 0.6274, Recall: 0.0776, AUC ROC: 0.5368
# Iteration 162/5000 - Accuracy: 0.9218, Precision: 0.6296, Recall: 0.0784, AUC ROC: 0.5372
# Iteration 163/5000 - Accuracy: 0.9218, Precision: 0.6272, Recall: 0.0801, AUC ROC: 0.5380
# Iteration 164/5000 - Accuracy: 0.9217, Precision: 0.6238, Recall: 0.0784, AUC ROC: 0.5371
# Iteration 165/5000 - Accuracy: 0.9218, Precision: 0.6286, Recall: 0.0806, AUC ROC: 0.5382
# Iteration 166/5000 - Accuracy: 0.9218, Precision: 0.6229, Recall: 0.0817, AUC ROC: 0.5387
# Iteration 167/5000 - Accuracy: 0.9219, Precision: 0.6314, Recall: 0.0808, AUC ROC: 0.5383
# Iteration 168/5000 - Accuracy: 0.9218, Precision: 0.6248, Recall: 0.0817, AUC ROC: 0.5387
# Iteration 169/5000 - Accuracy: 0.9219, Precision: 0.6270, Recall: 0.0825, AUC ROC: 0.5391
# Iteration 170/5000 - Accuracy: 0.9219, Precision: 0.6280, Recall: 0.0823, AUC ROC: 0.5390
# Iteration 171/5000 - Accuracy: 0.9219, Precision: 0.6283, Recall: 0.0821, AUC ROC: 0.5389
# Iteration 172/5000 - Accuracy: 0.9218, Precision: 0.6235, Recall: 0.0841, AUC ROC: 0.5398
# Iteration 173/5000 - Accuracy: 0.9218, Precision: 0.6202, Recall: 0.0838, AUC ROC: 0.5396
# Iteration 174/5000 - Accuracy: 0.9218, Precision: 0.6209, Recall: 0.0842, AUC ROC: 0.5398
# Iteration 175/5000 - Accuracy: 0.9218, Precision: 0.6226, Recall: 0.0844, AUC ROC: 0.5399
# Iteration 176/5000 - Accuracy: 0.9218, Precision: 0.6213, Recall: 0.0843, AUC ROC: 0.5399
# Iteration 177/5000 - Accuracy: 0.9218, Precision: 0.6187, Recall: 0.0859, AUC ROC: 0.5406
# Iteration 178/5000 - Accuracy: 0.9218, Precision: 0.6163, Recall: 0.0866, AUC ROC: 0.5409
# Iteration 179/5000 - Accuracy: 0.9218, Precision: 0.6204, Recall: 0.0847, AUC ROC: 0.5401
# Iteration 180/5000 - Accuracy: 0.9218, Precision: 0.6171, Recall: 0.0868, AUC ROC: 0.5410
# Iteration 181/5000 - Accuracy: 0.9218, Precision: 0.6182, Recall: 0.0848, AUC ROC: 0.5401
# Iteration 182/5000 - Accuracy: 0.9219, Precision: 0.6241, Recall: 0.0858, AUC ROC: 0.5407
# Iteration 183/5000 - Accuracy: 0.9218, Precision: 0.6226, Recall: 0.0839, AUC ROC: 0.5397
# Iteration 184/5000 - Accuracy: 0.9218, Precision: 0.6179, Recall: 0.0869, AUC ROC: 0.5411
# Iteration 185/5000 - Accuracy: 0.9219, Precision: 0.6209, Recall: 0.0866, AUC ROC: 0.5410
# Iteration 186/5000 - Accuracy: 0.9218, Precision: 0.6193, Recall: 0.0846, AUC ROC: 0.5400
# Iteration 187/5000 - Accuracy: 0.9218, Precision: 0.6194, Recall: 0.0845, AUC ROC: 0.5400
# Iteration 188/5000 - Accuracy: 0.9219, Precision: 0.6222, Recall: 0.0859, AUC ROC: 0.5407
# Iteration 189/5000 - Accuracy: 0.9218, Precision: 0.6201, Recall: 0.0857, AUC ROC: 0.5405
# Iteration 190/5000 - Accuracy: 0.9218, Precision: 0.6194, Recall: 0.0865, AUC ROC: 0.5409
# Iteration 191/5000 - Accuracy: 0.9218, Precision: 0.6125, Recall: 0.0891, AUC ROC: 0.5421
# Iteration 192/5000 - Accuracy: 0.9218, Precision: 0.6207, Recall: 0.0858, AUC ROC: 0.5406
# Iteration 193/5000 - Accuracy: 0.9218, Precision: 0.6180, Recall: 0.0871, AUC ROC: 0.5412
# Iteration 194/5000 - Accuracy: 0.9218, Precision: 0.6158, Recall: 0.0885, AUC ROC: 0.5418
# Iteration 195/5000 - Accuracy: 0.9218, Precision: 0.6124, Recall: 0.0879, AUC ROC: 0.5415
# Iteration 196/5000 - Accuracy: 0.9219, Precision: 0.6166, Recall: 0.0909, AUC ROC: 0.5430
# Iteration 197/5000 - Accuracy: 0.9220, Precision: 0.6200, Recall: 0.0904, AUC ROC: 0.5428
# Iteration 198/5000 - Accuracy: 0.9219, Precision: 0.6180, Recall: 0.0902, AUC ROC: 0.5426
# Iteration 199/5000 - Accuracy: 0.9219, Precision: 0.6194, Recall: 0.0890, AUC ROC: 0.5421
# Iteration 200/5000 - Accuracy: 0.9219, Precision: 0.6150, Recall: 0.0909, AUC ROC: 0.5429
# Iteration 201/5000 - Accuracy: 0.9219, Precision: 0.6167, Recall: 0.0898, AUC ROC: 0.5424
# Iteration 202/5000 - Accuracy: 0.9220, Precision: 0.6164, Recall: 0.0920, AUC ROC: 0.5435
# Iteration 203/5000 - Accuracy: 0.9219, Precision: 0.6146, Recall: 0.0913, AUC ROC: 0.5431
# Iteration 204/5000 - Accuracy: 0.9220, Precision: 0.6182, Recall: 0.0923, AUC ROC: 0.5436
# Iteration 205/5000 - Accuracy: 0.9220, Precision: 0.6197, Recall: 0.0925, AUC ROC: 0.5438
# Iteration 206/5000 - Accuracy: 0.9220, Precision: 0.6196, Recall: 0.0919, AUC ROC: 0.5435
# Iteration 207/5000 - Accuracy: 0.9219, Precision: 0.6145, Recall: 0.0915, AUC ROC: 0.5432
# Iteration 208/5000 - Accuracy: 0.9219, Precision: 0.6142, Recall: 0.0922, AUC ROC: 0.5436
# Iteration 209/5000 - Accuracy: 0.9220, Precision: 0.6185, Recall: 0.0913, AUC ROC: 0.5432
# Iteration 210/5000 - Accuracy: 0.9220, Precision: 0.6191, Recall: 0.0925, AUC ROC: 0.5437
# Iteration 211/5000 - Accuracy: 0.9219, Precision: 0.6149, Recall: 0.0904, AUC ROC: 0.5427
# Iteration 212/5000 - Accuracy: 0.9218, Precision: 0.6114, Recall: 0.0895, AUC ROC: 0.5422
# Iteration 213/5000 - Accuracy: 0.9219, Precision: 0.6177, Recall: 0.0882, AUC ROC: 0.5417
# Iteration 214/5000 - Accuracy: 0.9219, Precision: 0.6135, Recall: 0.0912, AUC ROC: 0.5431
# Iteration 215/5000 - Accuracy: 0.9219, Precision: 0.6139, Recall: 0.0913, AUC ROC: 0.5431
# Iteration 216/5000 - Accuracy: 0.9219, Precision: 0.6150, Recall: 0.0898, AUC ROC: 0.5424
# Iteration 217/5000 - Accuracy: 0.9219, Precision: 0.6138, Recall: 0.0918, AUC ROC: 0.5434
# Iteration 218/5000 - Accuracy: 0.9220, Precision: 0.6186, Recall: 0.0909, AUC ROC: 0.5430
# Iteration 219/5000 - Accuracy: 0.9218, Precision: 0.6144, Recall: 0.0897, AUC ROC: 0.5424
# Iteration 220/5000 - Accuracy: 0.9219, Precision: 0.6146, Recall: 0.0900, AUC ROC: 0.5425
# Iteration 221/5000 - Accuracy: 0.9220, Precision: 0.6179, Recall: 0.0928, AUC ROC: 0.5439
# Iteration 222/5000 - Accuracy: 0.9220, Precision: 0.6173, Recall: 0.0917, AUC ROC: 0.5434
# Iteration 223/5000 - Accuracy: 0.9219, Precision: 0.6157, Recall: 0.0921, AUC ROC: 0.5435
# Iteration 224/5000 - Accuracy: 0.9219, Precision: 0.6154, Recall: 0.0918, AUC ROC: 0.5434
# Iteration 225/5000 - Accuracy: 0.9219, Precision: 0.6153, Recall: 0.0913, AUC ROC: 0.5431
# Iteration 226/5000 - Accuracy: 0.9220, Precision: 0.6171, Recall: 0.0914, AUC ROC: 0.5432
# Iteration 227/5000 - Accuracy: 0.9221, Precision: 0.6237, Recall: 0.0905, AUC ROC: 0.5429
# Iteration 228/5000 - Accuracy: 0.9220, Precision: 0.6153, Recall: 0.0928, AUC ROC: 0.5439
# Iteration 229/5000 - Accuracy: 0.9219, Precision: 0.6144, Recall: 0.0917, AUC ROC: 0.5433
# Iteration 230/5000 - Accuracy: 0.9218, Precision: 0.6117, Recall: 0.0907, AUC ROC: 0.5428
# Iteration 231/5000 - Accuracy: 0.9218, Precision: 0.6070, Recall: 0.0924, AUC ROC: 0.5436
# Iteration 232/5000 - Accuracy: 0.9219, Precision: 0.6145, Recall: 0.0900, AUC ROC: 0.5425
# Iteration 233/5000 - Accuracy: 0.9219, Precision: 0.6123, Recall: 0.0919, AUC ROC: 0.5434
# Iteration 234/5000 - Accuracy: 0.9219, Precision: 0.6156, Recall: 0.0916, AUC ROC: 0.5433
# Iteration 235/5000 - Accuracy: 0.9220, Precision: 0.6180, Recall: 0.0915, AUC ROC: 0.5433
# Iteration 236/5000 - Accuracy: 0.9220, Precision: 0.6166, Recall: 0.0935, AUC ROC: 0.5442
# Iteration 237/5000 - Accuracy: 0.9220, Precision: 0.6164, Recall: 0.0944, AUC ROC: 0.5446
# Iteration 238/5000 - Accuracy: 0.9220, Precision: 0.6171, Recall: 0.0930, AUC ROC: 0.5440
# Iteration 239/5000 - Accuracy: 0.9219, Precision: 0.6138, Recall: 0.0929, AUC ROC: 0.5439
# Iteration 240/5000 - Accuracy: 0.9221, Precision: 0.6183, Recall: 0.0938, AUC ROC: 0.5444
# Iteration 241/5000 - Accuracy: 0.9218, Precision: 0.6103, Recall: 0.0920, AUC ROC: 0.5434
# Iteration 242/5000 - Accuracy: 0.9219, Precision: 0.6140, Recall: 0.0925, AUC ROC: 0.5437
# Iteration 243/5000 - Accuracy: 0.9220, Precision: 0.6178, Recall: 0.0939, AUC ROC: 0.5444
# Iteration 244/5000 - Accuracy: 0.9221, Precision: 0.6178, Recall: 0.0945, AUC ROC: 0.5447
# Iteration 245/5000 - Accuracy: 0.9221, Precision: 0.6191, Recall: 0.0941, AUC ROC: 0.5445
# Iteration 246/5000 - Accuracy: 0.9221, Precision: 0.6196, Recall: 0.0932, AUC ROC: 0.5441
# Iteration 247/5000 - Accuracy: 0.9220, Precision: 0.6143, Recall: 0.0954, AUC ROC: 0.5450
# Iteration 248/5000 - Accuracy: 0.9221, Precision: 0.6212, Recall: 0.0949, AUC ROC: 0.5449
# Iteration 249/5000 - Accuracy: 0.9220, Precision: 0.6160, Recall: 0.0938, AUC ROC: 0.5443
# Iteration 250/5000 - Accuracy: 0.9221, Precision: 0.6163, Recall: 0.0974, AUC ROC: 0.5460
# Iteration 251/5000 - Accuracy: 0.9221, Precision: 0.6169, Recall: 0.0963, AUC ROC: 0.5455
# Iteration 252/5000 - Accuracy: 0.9220, Precision: 0.6134, Recall: 0.0952, AUC ROC: 0.5450
# Iteration 253/5000 - Accuracy: 0.9221, Precision: 0.6144, Recall: 0.0965, AUC ROC: 0.5456
# Iteration 254/5000 - Accuracy: 0.9221, Precision: 0.6145, Recall: 0.0965, AUC ROC: 0.5456
# Iteration 255/5000 - Accuracy: 0.9221, Precision: 0.6150, Recall: 0.0966, AUC ROC: 0.5456
# Iteration 256/5000 - Accuracy: 0.9220, Precision: 0.6131, Recall: 0.0954, AUC ROC: 0.5451
# Iteration 257/5000 - Accuracy: 0.9220, Precision: 0.6140, Recall: 0.0964, AUC ROC: 0.5455
# Iteration 258/5000 - Accuracy: 0.9221, Precision: 0.6159, Recall: 0.0974, AUC ROC: 0.5460
# Iteration 259/5000 - Accuracy: 0.9221, Precision: 0.6148, Recall: 0.0962, AUC ROC: 0.5455
# Iteration 260/5000 - Accuracy: 0.9221, Precision: 0.6146, Recall: 0.0968, AUC ROC: 0.5457
# Iteration 261/5000 - Accuracy: 0.9221, Precision: 0.6174, Recall: 0.0957, AUC ROC: 0.5452
# Iteration 262/5000 - Accuracy: 0.9221, Precision: 0.6157, Recall: 0.0959, AUC ROC: 0.5453
# Iteration 263/5000 - Accuracy: 0.9221, Precision: 0.6152, Recall: 0.0970, AUC ROC: 0.5458
# Iteration 264/5000 - Accuracy: 0.9220, Precision: 0.6115, Recall: 0.0958, AUC ROC: 0.5452
# Iteration 265/5000 - Accuracy: 0.9220, Precision: 0.6159, Recall: 0.0953, AUC ROC: 0.5450
# Iteration 266/5000 - Accuracy: 0.9221, Precision: 0.6199, Recall: 0.0959, AUC ROC: 0.5454
# Iteration 267/5000 - Accuracy: 0.9221, Precision: 0.6146, Recall: 0.0972, AUC ROC: 0.5459
# Iteration 268/5000 - Accuracy: 0.9222, Precision: 0.6207, Recall: 0.0964, AUC ROC: 0.5456
# Iteration 269/5000 - Accuracy: 0.9221, Precision: 0.6173, Recall: 0.0955, AUC ROC: 0.5452
# Iteration 270/5000 - Accuracy: 0.9221, Precision: 0.6175, Recall: 0.0947, AUC ROC: 0.5448
# Iteration 271/5000 - Accuracy: 0.9221, Precision: 0.6185, Recall: 0.0943, AUC ROC: 0.5446
# Iteration 272/5000 - Accuracy: 0.9222, Precision: 0.6203, Recall: 0.0967, AUC ROC: 0.5457
# Iteration 273/5000 - Accuracy: 0.9222, Precision: 0.6218, Recall: 0.0969, AUC ROC: 0.5458
# Iteration 274/5000 - Accuracy: 0.9221, Precision: 0.6192, Recall: 0.0961, AUC ROC: 0.5454
# Iteration 275/5000 - Accuracy: 0.9222, Precision: 0.6243, Recall: 0.0952, AUC ROC: 0.5451
# Iteration 276/5000 - Accuracy: 0.9221, Precision: 0.6183, Recall: 0.0958, AUC ROC: 0.5453
# Iteration 277/5000 - Accuracy: 0.9222, Precision: 0.6242, Recall: 0.0952, AUC ROC: 0.5451
# Iteration 278/5000 - Accuracy: 0.9222, Precision: 0.6206, Recall: 0.0960, AUC ROC: 0.5454
# Iteration 279/5000 - Accuracy: 0.9223, Precision: 0.6225, Recall: 0.0977, AUC ROC: 0.5462
# Iteration 280/5000 - Accuracy: 0.9222, Precision: 0.6168, Recall: 0.0989, AUC ROC: 0.5467
# Iteration 281/5000 - Accuracy: 0.9223, Precision: 0.6235, Recall: 0.0971, AUC ROC: 0.5460
# Iteration 282/5000 - Accuracy: 0.9223, Precision: 0.6253, Recall: 0.0977, AUC ROC: 0.5463
# Iteration 283/5000 - Accuracy: 0.9223, Precision: 0.6237, Recall: 0.0983, AUC ROC: 0.5465
# Iteration 284/5000 - Accuracy: 0.9223, Precision: 0.6236, Recall: 0.0984, AUC ROC: 0.5466
# Iteration 285/5000 - Accuracy: 0.9223, Precision: 0.6246, Recall: 0.0977, AUC ROC: 0.5463
# Iteration 286/5000 - Accuracy: 0.9222, Precision: 0.6234, Recall: 0.0965, AUC ROC: 0.5457
# Iteration 287/5000 - Accuracy: 0.9223, Precision: 0.6236, Recall: 0.0984, AUC ROC: 0.5466
# Iteration 288/5000 - Accuracy: 0.9223, Precision: 0.6292, Recall: 0.0963, AUC ROC: 0.5457
# Iteration 289/5000 - Accuracy: 0.9223, Precision: 0.6281, Recall: 0.0959, AUC ROC: 0.5454
# Iteration 290/5000 - Accuracy: 0.9224, Precision: 0.6289, Recall: 0.0975, AUC ROC: 0.5462
# Iteration 291/5000 - Accuracy: 0.9225, Precision: 0.6307, Recall: 0.0986, AUC ROC: 0.5467
# Iteration 292/5000 - Accuracy: 0.9224, Precision: 0.6298, Recall: 0.0963, AUC ROC: 0.5457
# Iteration 293/5000 - Accuracy: 0.9224, Precision: 0.6299, Recall: 0.0986, AUC ROC: 0.5467
# Iteration 294/5000 - Accuracy: 0.9224, Precision: 0.6317, Recall: 0.0971, AUC ROC: 0.5461
# Iteration 295/5000 - Accuracy: 0.9224, Precision: 0.6268, Recall: 0.0984, AUC ROC: 0.5466
# Iteration 296/5000 - Accuracy: 0.9224, Precision: 0.6273, Recall: 0.0994, AUC ROC: 0.5471
# Iteration 297/5000 - Accuracy: 0.9224, Precision: 0.6294, Recall: 0.0977, AUC ROC: 0.5463
# Iteration 298/5000 - Accuracy: 0.9224, Precision: 0.6276, Recall: 0.0984, AUC ROC: 0.5466
# Iteration 299/5000 - Accuracy: 0.9224, Precision: 0.6297, Recall: 0.0977, AUC ROC: 0.5463
# Iteration 300/5000 - Accuracy: 0.9224, Precision: 0.6278, Recall: 0.0979, AUC ROC: 0.5464
# Iteration 301/5000 - Accuracy: 0.9223, Precision: 0.6321, Recall: 0.0943, AUC ROC: 0.5447
# Iteration 302/5000 - Accuracy: 0.9224, Precision: 0.6346, Recall: 0.0951, AUC ROC: 0.5451
# Iteration 303/5000 - Accuracy: 0.9224, Precision: 0.6352, Recall: 0.0953, AUC ROC: 0.5452
# Iteration 304/5000 - Accuracy: 0.9224, Precision: 0.6356, Recall: 0.0953, AUC ROC: 0.5452
# Iteration 305/5000 - Accuracy: 0.9225, Precision: 0.6350, Recall: 0.0962, AUC ROC: 0.5456
# Iteration 306/5000 - Accuracy: 0.9224, Precision: 0.6314, Recall: 0.0959, AUC ROC: 0.5455
# Iteration 307/5000 - Accuracy: 0.9225, Precision: 0.6391, Recall: 0.0955, AUC ROC: 0.5454
# Iteration 308/5000 - Accuracy: 0.9224, Precision: 0.6329, Recall: 0.0961, AUC ROC: 0.5456
# Iteration 309/5000 - Accuracy: 0.9225, Precision: 0.6368, Recall: 0.0954, AUC ROC: 0.5453
# Iteration 310/5000 - Accuracy: 0.9225, Precision: 0.6356, Recall: 0.0973, AUC ROC: 0.5462
# Iteration 311/5000 - Accuracy: 0.9224, Precision: 0.6379, Recall: 0.0939, AUC ROC: 0.5446
# Iteration 312/5000 - Accuracy: 0.9225, Precision: 0.6364, Recall: 0.0954, AUC ROC: 0.5453
# Iteration 313/5000 - Accuracy: 0.9225, Precision: 0.6396, Recall: 0.0959, AUC ROC: 0.5456
# Iteration 314/5000 - Accuracy: 0.9225, Precision: 0.6383, Recall: 0.0955, AUC ROC: 0.5454
# Iteration 315/5000 - Accuracy: 0.9225, Precision: 0.6393, Recall: 0.0957, AUC ROC: 0.5455
# Iteration 316/5000 - Accuracy: 0.9225, Precision: 0.6354, Recall: 0.0968, AUC ROC: 0.5459
# Iteration 317/5000 - Accuracy: 0.9225, Precision: 0.6385, Recall: 0.0966, AUC ROC: 0.5459
# Iteration 318/5000 - Accuracy: 0.9225, Precision: 0.6356, Recall: 0.0980, AUC ROC: 0.5465
# Iteration 319/5000 - Accuracy: 0.9225, Precision: 0.6397, Recall: 0.0954, AUC ROC: 0.5453
# Iteration 320/5000 - Accuracy: 0.9225, Precision: 0.6347, Recall: 0.0966, AUC ROC: 0.5458
# Iteration 321/5000 - Accuracy: 0.9225, Precision: 0.6373, Recall: 0.0969, AUC ROC: 0.5460
# Iteration 322/5000 - Accuracy: 0.9225, Precision: 0.6328, Recall: 0.0976, AUC ROC: 0.5463
# Iteration 323/5000 - Accuracy: 0.9225, Precision: 0.6348, Recall: 0.0962, AUC ROC: 0.5456
# Iteration 324/5000 - Accuracy: 0.9226, Precision: 0.6374, Recall: 0.0981, AUC ROC: 0.5466
# Iteration 325/5000 - Accuracy: 0.9225, Precision: 0.6356, Recall: 0.0984, AUC ROC: 0.5467
# Iteration 326/5000 - Accuracy: 0.9225, Precision: 0.6351, Recall: 0.0979, AUC ROC: 0.5465
# Iteration 327/5000 - Accuracy: 0.9225, Precision: 0.6356, Recall: 0.0975, AUC ROC: 0.5463
# Iteration 328/5000 - Accuracy: 0.9225, Precision: 0.6383, Recall: 0.0967, AUC ROC: 0.5459
# Iteration 329/5000 - Accuracy: 0.9225, Precision: 0.6372, Recall: 0.0970, AUC ROC: 0.5461
# Iteration 330/5000 - Accuracy: 0.9225, Precision: 0.6359, Recall: 0.0970, AUC ROC: 0.5460
# Iteration 331/5000 - Accuracy: 0.9226, Precision: 0.6371, Recall: 0.0990, AUC ROC: 0.5470
# Iteration 332/5000 - Accuracy: 0.9225, Precision: 0.6327, Recall: 0.0988, AUC ROC: 0.5469
# Iteration 333/5000 - Accuracy: 0.9224, Precision: 0.6333, Recall: 0.0961, AUC ROC: 0.5456
# Iteration 334/5000 - Accuracy: 0.9226, Precision: 0.6381, Recall: 0.1000, AUC ROC: 0.5475
# Iteration 335/5000 - Accuracy: 0.9226, Precision: 0.6371, Recall: 0.0978, AUC ROC: 0.5465
# Iteration 336/5000 - Accuracy: 0.9225, Precision: 0.6344, Recall: 0.0990, AUC ROC: 0.5470
# Iteration 337/5000 - Accuracy: 0.9225, Precision: 0.6300, Recall: 0.1018, AUC ROC: 0.5483
# Iteration 338/5000 - Accuracy: 0.9226, Precision: 0.6391, Recall: 0.0984, AUC ROC: 0.5468
# Iteration 339/5000 - Accuracy: 0.9225, Precision: 0.6320, Recall: 0.0988, AUC ROC: 0.5469
# Iteration 340/5000 - Accuracy: 0.9225, Precision: 0.6318, Recall: 0.0989, AUC ROC: 0.5469
# Iteration 341/5000 - Accuracy: 0.9226, Precision: 0.6354, Recall: 0.0995, AUC ROC: 0.5472
# Iteration 342/5000 - Accuracy: 0.9225, Precision: 0.6308, Recall: 0.1009, AUC ROC: 0.5479
# Iteration 343/5000 - Accuracy: 0.9225, Precision: 0.6333, Recall: 0.0997, AUC ROC: 0.5473
# Iteration 344/5000 - Accuracy: 0.9225, Precision: 0.6302, Recall: 0.1008, AUC ROC: 0.5478
# Iteration 345/5000 - Accuracy: 0.9226, Precision: 0.6372, Recall: 0.0990, AUC ROC: 0.5470
# Iteration 346/5000 - Accuracy: 0.9226, Precision: 0.6338, Recall: 0.1003, AUC ROC: 0.5476
# Iteration 347/5000 - Accuracy: 0.9225, Precision: 0.6305, Recall: 0.1011, AUC ROC: 0.5480
# Iteration 348/5000 - Accuracy: 0.9225, Precision: 0.6308, Recall: 0.1003, AUC ROC: 0.5476
# Iteration 349/5000 - Accuracy: 0.9226, Precision: 0.6328, Recall: 0.1005, AUC ROC: 0.5477
# Iteration 350/5000 - Accuracy: 0.9224, Precision: 0.6250, Recall: 0.1005, AUC ROC: 0.5476
# Iteration 351/5000 - Accuracy: 0.9224, Precision: 0.6261, Recall: 0.1008, AUC ROC: 0.5477
# Iteration 352/5000 - Accuracy: 0.9225, Precision: 0.6278, Recall: 0.1006, AUC ROC: 0.5477
# Iteration 353/5000 - Accuracy: 0.9224, Precision: 0.6262, Recall: 0.1011, AUC ROC: 0.5479
# Iteration 354/5000 - Accuracy: 0.9225, Precision: 0.6262, Recall: 0.1015, AUC ROC: 0.5481
# Iteration 355/5000 - Accuracy: 0.9224, Precision: 0.6223, Recall: 0.1024, AUC ROC: 0.5485
# Iteration 356/5000 - Accuracy: 0.9224, Precision: 0.6228, Recall: 0.1018, AUC ROC: 0.5482
# Iteration 357/5000 - Accuracy: 0.9225, Precision: 0.6256, Recall: 0.1026, AUC ROC: 0.5486
# Iteration 358/5000 - Accuracy: 0.9225, Precision: 0.6275, Recall: 0.1027, AUC ROC: 0.5487
# Iteration 359/5000 - Accuracy: 0.9225, Precision: 0.6258, Recall: 0.1032, AUC ROC: 0.5489
# Iteration 360/5000 - Accuracy: 0.9225, Precision: 0.6254, Recall: 0.1039, AUC ROC: 0.5492
# Iteration 361/5000 - Accuracy: 0.9225, Precision: 0.6240, Recall: 0.1042, AUC ROC: 0.5493
# Iteration 362/5000 - Accuracy: 0.9225, Precision: 0.6248, Recall: 0.1044, AUC ROC: 0.5494
# Iteration 363/5000 - Accuracy: 0.9226, Precision: 0.6277, Recall: 0.1040, AUC ROC: 0.5493
# Iteration 364/5000 - Accuracy: 0.9224, Precision: 0.6226, Recall: 0.1035, AUC ROC: 0.5490
# Iteration 365/5000 - Accuracy: 0.9225, Precision: 0.6250, Recall: 0.1048, AUC ROC: 0.5496
# Iteration 366/5000 - Accuracy: 0.9225, Precision: 0.6211, Recall: 0.1054, AUC ROC: 0.5499
# Iteration 367/5000 - Accuracy: 0.9225, Precision: 0.6213, Recall: 0.1052, AUC ROC: 0.5498
# Iteration 368/5000 - Accuracy: 0.9224, Precision: 0.6181, Recall: 0.1059, AUC ROC: 0.5501
# Iteration 369/5000 - Accuracy: 0.9225, Precision: 0.6214, Recall: 0.1061, AUC ROC: 0.5502
# Iteration 370/5000 - Accuracy: 0.9225, Precision: 0.6186, Recall: 0.1085, AUC ROC: 0.5513
# Iteration 371/5000 - Accuracy: 0.9224, Precision: 0.6143, Recall: 0.1093, AUC ROC: 0.5516
# Iteration 372/5000 - Accuracy: 0.9224, Precision: 0.6163, Recall: 0.1068, AUC ROC: 0.5505
# Iteration 373/5000 - Accuracy: 0.9225, Precision: 0.6180, Recall: 0.1081, AUC ROC: 0.5511
# Iteration 374/5000 - Accuracy: 0.9224, Precision: 0.6152, Recall: 0.1067, AUC ROC: 0.5504
# Iteration 375/5000 - Accuracy: 0.9225, Precision: 0.6163, Recall: 0.1085, AUC ROC: 0.5513
# Iteration 376/5000 - Accuracy: 0.9225, Precision: 0.6193, Recall: 0.1063, AUC ROC: 0.5503
# Iteration 377/5000 - Accuracy: 0.9225, Precision: 0.6212, Recall: 0.1064, AUC ROC: 0.5503
# Iteration 378/5000 - Accuracy: 0.9224, Precision: 0.6180, Recall: 0.1064, AUC ROC: 0.5503
# Iteration 379/5000 - Accuracy: 0.9224, Precision: 0.6157, Recall: 0.1071, AUC ROC: 0.5506
# Iteration 380/5000 - Accuracy: 0.9224, Precision: 0.6175, Recall: 0.1071, AUC ROC: 0.5506
# Iteration 381/5000 - Accuracy: 0.9223, Precision: 0.6114, Recall: 0.1077, AUC ROC: 0.5508
# Iteration 382/5000 - Accuracy: 0.9224, Precision: 0.6168, Recall: 0.1069, AUC ROC: 0.5505
# Iteration 383/5000 - Accuracy: 0.9225, Precision: 0.6169, Recall: 0.1083, AUC ROC: 0.5512
# Iteration 384/5000 - Accuracy: 0.9224, Precision: 0.6146, Recall: 0.1094, AUC ROC: 0.5517
# Iteration 385/5000 - Accuracy: 0.9225, Precision: 0.6181, Recall: 0.1069, AUC ROC: 0.5505
# Iteration 386/5000 - Accuracy: 0.9224, Precision: 0.6149, Recall: 0.1081, AUC ROC: 0.5511
# Iteration 387/5000 - Accuracy: 0.9224, Precision: 0.6139, Recall: 0.1082, AUC ROC: 0.5511
# Iteration 388/5000 - Accuracy: 0.9224, Precision: 0.6152, Recall: 0.1084, AUC ROC: 0.5512
# Iteration 389/5000 - Accuracy: 0.9224, Precision: 0.6126, Recall: 0.1095, AUC ROC: 0.5517
# Iteration 390/5000 - Accuracy: 0.9224, Precision: 0.6137, Recall: 0.1078, AUC ROC: 0.5509
# Iteration 391/5000 - Accuracy: 0.9223, Precision: 0.6118, Recall: 0.1082, AUC ROC: 0.5511
# Iteration 392/5000 - Accuracy: 0.9223, Precision: 0.6128, Recall: 0.1059, AUC ROC: 0.5500
# Iteration 393/5000 - Accuracy: 0.9225, Precision: 0.6183, Recall: 0.1075, AUC ROC: 0.5508
# Iteration 394/5000 - Accuracy: 0.9224, Precision: 0.6145, Recall: 0.1069, AUC ROC: 0.5505
# Iteration 395/5000 - Accuracy: 0.9224, Precision: 0.6153, Recall: 0.1074, AUC ROC: 0.5507
# Iteration 396/5000 - Accuracy: 0.9224, Precision: 0.6164, Recall: 0.1068, AUC ROC: 0.5505
# Iteration 397/5000 - Accuracy: 0.9222, Precision: 0.6062, Recall: 0.1078, AUC ROC: 0.5508
# Iteration 398/5000 - Accuracy: 0.9224, Precision: 0.6128, Recall: 0.1084, AUC ROC: 0.5512
# Iteration 399/5000 - Accuracy: 0.9224, Precision: 0.6142, Recall: 0.1073, AUC ROC: 0.5507
# Iteration 400/5000 - Accuracy: 0.9224, Precision: 0.6136, Recall: 0.1078, AUC ROC: 0.5509
# Iteration 401/5000 - Accuracy: 0.9224, Precision: 0.6131, Recall: 0.1077, AUC ROC: 0.5509
# Iteration 402/5000 - Accuracy: 0.9224, Precision: 0.6137, Recall: 0.1075, AUC ROC: 0.5508
# Iteration 403/5000 - Accuracy: 0.9224, Precision: 0.6128, Recall: 0.1092, AUC ROC: 0.5516
# Iteration 404/5000 - Accuracy: 0.9224, Precision: 0.6146, Recall: 0.1078, AUC ROC: 0.5509
# Iteration 405/5000 - Accuracy: 0.9224, Precision: 0.6149, Recall: 0.1071, AUC ROC: 0.5506
# Iteration 406/5000 - Accuracy: 0.9224, Precision: 0.6168, Recall: 0.1067, AUC ROC: 0.5504
# Iteration 407/5000 - Accuracy: 0.9225, Precision: 0.6214, Recall: 0.1057, AUC ROC: 0.5500
# Iteration 408/5000 - Accuracy: 0.9225, Precision: 0.6180, Recall: 0.1079, AUC ROC: 0.5510
# Iteration 409/5000 - Accuracy: 0.9225, Precision: 0.6199, Recall: 0.1074, AUC ROC: 0.5508
# Iteration 410/5000 - Accuracy: 0.9224, Precision: 0.6175, Recall: 0.1066, AUC ROC: 0.5504
# Iteration 411/5000 - Accuracy: 0.9225, Precision: 0.6217, Recall: 0.1072, AUC ROC: 0.5507
# Iteration 412/5000 - Accuracy: 0.9225, Precision: 0.6222, Recall: 0.1056, AUC ROC: 0.5500
# Iteration 413/5000 - Accuracy: 0.9224, Precision: 0.6186, Recall: 0.1064, AUC ROC: 0.5503
# Iteration 414/5000 - Accuracy: 0.9225, Precision: 0.6178, Recall: 0.1078, AUC ROC: 0.5510
# Iteration 415/5000 - Accuracy: 0.9225, Precision: 0.6191, Recall: 0.1067, AUC ROC: 0.5505
# Iteration 416/5000 - Accuracy: 0.9225, Precision: 0.6226, Recall: 0.1058, AUC ROC: 0.5501
# Iteration 417/5000 - Accuracy: 0.9225, Precision: 0.6179, Recall: 0.1079, AUC ROC: 0.5510
# Iteration 418/5000 - Accuracy: 0.9224, Precision: 0.6164, Recall: 0.1067, AUC ROC: 0.5504
# Iteration 419/5000 - Accuracy: 0.9224, Precision: 0.6189, Recall: 0.1061, AUC ROC: 0.5502
# Iteration 420/5000 - Accuracy: 0.9223, Precision: 0.6120, Recall: 0.1073, AUC ROC: 0.5507
# Iteration 421/5000 - Accuracy: 0.9224, Precision: 0.6164, Recall: 0.1067, AUC ROC: 0.5504
# Iteration 422/5000 - Accuracy: 0.9224, Precision: 0.6172, Recall: 0.1073, AUC ROC: 0.5507
# Iteration 423/5000 - Accuracy: 0.9223, Precision: 0.6132, Recall: 0.1068, AUC ROC: 0.5504
# Iteration 424/5000 - Accuracy: 0.9224, Precision: 0.6154, Recall: 0.1067, AUC ROC: 0.5504
# Iteration 425/5000 - Accuracy: 0.9223, Precision: 0.6136, Recall: 0.1067, AUC ROC: 0.5504
# Iteration 426/5000 - Accuracy: 0.9225, Precision: 0.6187, Recall: 0.1078, AUC ROC: 0.5510
# Iteration 427/5000 - Accuracy: 0.9223, Precision: 0.6119, Recall: 0.1081, AUC ROC: 0.5510
# Iteration 428/5000 - Accuracy: 0.9224, Precision: 0.6160, Recall: 0.1066, AUC ROC: 0.5504
# Iteration 429/5000 - Accuracy: 0.9223, Precision: 0.6140, Recall: 0.1065, AUC ROC: 0.5503
# Iteration 430/5000 - Accuracy: 0.9224, Precision: 0.6185, Recall: 0.1060, AUC ROC: 0.5501
# Iteration 431/5000 - Accuracy: 0.9224, Precision: 0.6189, Recall: 0.1057, AUC ROC: 0.5500
# Iteration 432/5000 - Accuracy: 0.9224, Precision: 0.6149, Recall: 0.1065, AUC ROC: 0.5503
# Iteration 433/5000 - Accuracy: 0.9225, Precision: 0.6179, Recall: 0.1073, AUC ROC: 0.5507
# Iteration 434/5000 - Accuracy: 0.9223, Precision: 0.6144, Recall: 0.1058, AUC ROC: 0.5500
# Iteration 435/5000 - Accuracy: 0.9224, Precision: 0.6171, Recall: 0.1075, AUC ROC: 0.5508
# Iteration 436/5000 - Accuracy: 0.9224, Precision: 0.6189, Recall: 0.1061, AUC ROC: 0.5502
# Iteration 437/5000 - Accuracy: 0.9224, Precision: 0.6148, Recall: 0.1061, AUC ROC: 0.5501
# Iteration 438/5000 - Accuracy: 0.9225, Precision: 0.6186, Recall: 0.1073, AUC ROC: 0.5507
# Iteration 439/5000 - Accuracy: 0.9224, Precision: 0.6175, Recall: 0.1060, AUC ROC: 0.5501
# Iteration 440/5000 - Accuracy: 0.9224, Precision: 0.6189, Recall: 0.1060, AUC ROC: 0.5501
# Iteration 441/5000 - Accuracy: 0.9225, Precision: 0.6182, Recall: 0.1070, AUC ROC: 0.5506
# Iteration 442/5000 - Accuracy: 0.9225, Precision: 0.6199, Recall: 0.1066, AUC ROC: 0.5504
# Iteration 443/5000 - Accuracy: 0.9224, Precision: 0.6157, Recall: 0.1074, AUC ROC: 0.5507
# Iteration 444/5000 - Accuracy: 0.9225, Precision: 0.6200, Recall: 0.1072, AUC ROC: 0.5507
# Iteration 445/5000 - Accuracy: 0.9225, Precision: 0.6233, Recall: 0.1057, AUC ROC: 0.5500
# Iteration 446/5000 - Accuracy: 0.9226, Precision: 0.6258, Recall: 0.1070, AUC ROC: 0.5507
# Iteration 447/5000 - Accuracy: 0.9225, Precision: 0.6193, Recall: 0.1068, AUC ROC: 0.5505
# Iteration 448/5000 - Accuracy: 0.9224, Precision: 0.6190, Recall: 0.1053, AUC ROC: 0.5498
# Iteration 449/5000 - Accuracy: 0.9225, Precision: 0.6180, Recall: 0.1095, AUC ROC: 0.5518
# Iteration 450/5000 - Accuracy: 0.9225, Precision: 0.6196, Recall: 0.1062, AUC ROC: 0.5502
# Iteration 451/5000 - Accuracy: 0.9225, Precision: 0.6198, Recall: 0.1064, AUC ROC: 0.5503
# Iteration 452/5000 - Accuracy: 0.9225, Precision: 0.6201, Recall: 0.1079, AUC ROC: 0.5510
# Iteration 453/5000 - Accuracy: 0.9226, Precision: 0.6238, Recall: 0.1062, AUC ROC: 0.5503
# Iteration 454/5000 - Accuracy: 0.9225, Precision: 0.6213, Recall: 0.1054, AUC ROC: 0.5499
# Iteration 455/5000 - Accuracy: 0.9225, Precision: 0.6235, Recall: 0.1054, AUC ROC: 0.5499
# Iteration 456/5000 - Accuracy: 0.9225, Precision: 0.6212, Recall: 0.1062, AUC ROC: 0.5503
# Iteration 457/5000 - Accuracy: 0.9225, Precision: 0.6216, Recall: 0.1051, AUC ROC: 0.5497
# Iteration 458/5000 - Accuracy: 0.9224, Precision: 0.6202, Recall: 0.1049, AUC ROC: 0.5496
# Iteration 459/5000 - Accuracy: 0.9225, Precision: 0.6199, Recall: 0.1060, AUC ROC: 0.5501
# Iteration 460/5000 - Accuracy: 0.9224, Precision: 0.6202, Recall: 0.1052, AUC ROC: 0.5498
# Iteration 461/5000 - Accuracy: 0.9226, Precision: 0.6242, Recall: 0.1058, AUC ROC: 0.5501
# Iteration 462/5000 - Accuracy: 0.9225, Precision: 0.6219, Recall: 0.1057, AUC ROC: 0.5500
# Iteration 463/5000 - Accuracy: 0.9224, Precision: 0.6170, Recall: 0.1053, AUC ROC: 0.5498
# Iteration 464/5000 - Accuracy: 0.9224, Precision: 0.6219, Recall: 0.1036, AUC ROC: 0.5490
# Iteration 465/5000 - Accuracy: 0.9225, Precision: 0.6229, Recall: 0.1050, AUC ROC: 0.5497
# Iteration 466/5000 - Accuracy: 0.9224, Precision: 0.6193, Recall: 0.1045, AUC ROC: 0.5494
# Iteration 467/5000 - Accuracy: 0.9225, Precision: 0.6232, Recall: 0.1052, AUC ROC: 0.5498
# Iteration 468/5000 - Accuracy: 0.9224, Precision: 0.6207, Recall: 0.1040, AUC ROC: 0.5492
# Iteration 469/5000 - Accuracy: 0.9224, Precision: 0.6199, Recall: 0.1047, AUC ROC: 0.5495
# Iteration 470/5000 - Accuracy: 0.9225, Precision: 0.6258, Recall: 0.1027, AUC ROC: 0.5487
# Iteration 471/5000 - Accuracy: 0.9225, Precision: 0.6224, Recall: 0.1045, AUC ROC: 0.5494
# Iteration 472/5000 - Accuracy: 0.9224, Precision: 0.6219, Recall: 0.1025, AUC ROC: 0.5485
# Iteration 473/5000 - Accuracy: 0.9224, Precision: 0.6214, Recall: 0.1043, AUC ROC: 0.5493
# Iteration 474/5000 - Accuracy: 0.9224, Precision: 0.6209, Recall: 0.1040, AUC ROC: 0.5492
# Iteration 475/5000 - Accuracy: 0.9225, Precision: 0.6212, Recall: 0.1047, AUC ROC: 0.5495
# Iteration 476/5000 - Accuracy: 0.9225, Precision: 0.6251, Recall: 0.1045, AUC ROC: 0.5495
# Iteration 477/5000 - Accuracy: 0.9225, Precision: 0.6227, Recall: 0.1046, AUC ROC: 0.5495
# Iteration 478/5000 - Accuracy: 0.9225, Precision: 0.6219, Recall: 0.1062, AUC ROC: 0.5503
# Iteration 479/5000 - Accuracy: 0.9225, Precision: 0.6256, Recall: 0.1039, AUC ROC: 0.5492
# Iteration 480/5000 - Accuracy: 0.9226, Precision: 0.6246, Recall: 0.1057, AUC ROC: 0.5500
# Iteration 481/5000 - Accuracy: 0.9225, Precision: 0.6294, Recall: 0.1014, AUC ROC: 0.5481
# Iteration 482/5000 - Accuracy: 0.9226, Precision: 0.6295, Recall: 0.1043, AUC ROC: 0.5494
# Iteration 483/5000 - Accuracy: 0.9225, Precision: 0.6208, Recall: 0.1050, AUC ROC: 0.5497
# Iteration 484/5000 - Accuracy: 0.9226, Precision: 0.6295, Recall: 0.1050, AUC ROC: 0.5498
# Iteration 485/5000 - Accuracy: 0.9226, Precision: 0.6247, Recall: 0.1063, AUC ROC: 0.5504
# Iteration 486/5000 - Accuracy: 0.9225, Precision: 0.6233, Recall: 0.1049, AUC ROC: 0.5497
# Iteration 487/5000 - Accuracy: 0.9225, Precision: 0.6231, Recall: 0.1060, AUC ROC: 0.5502
# Iteration 488/5000 - Accuracy: 0.9226, Precision: 0.6290, Recall: 0.1052, AUC ROC: 0.5499
# Iteration 489/5000 - Accuracy: 0.9225, Precision: 0.6222, Recall: 0.1049, AUC ROC: 0.5496
# Iteration 490/5000 - Accuracy: 0.9225, Precision: 0.6249, Recall: 0.1039, AUC ROC: 0.5492
# Iteration 491/5000 - Accuracy: 0.9225, Precision: 0.6258, Recall: 0.1044, AUC ROC: 0.5494
# Iteration 492/5000 - Accuracy: 0.9225, Precision: 0.6246, Recall: 0.1041, AUC ROC: 0.5493
# Iteration 493/5000 - Accuracy: 0.9226, Precision: 0.6262, Recall: 0.1048, AUC ROC: 0.5497
# Iteration 494/5000 - Accuracy: 0.9226, Precision: 0.6290, Recall: 0.1046, AUC ROC: 0.5496
# Iteration 495/5000 - Accuracy: 0.9226, Precision: 0.6260, Recall: 0.1057, AUC ROC: 0.5501
# Iteration 496/5000 - Accuracy: 0.9225, Precision: 0.6244, Recall: 0.1050, AUC ROC: 0.5497
# Iteration 497/5000 - Accuracy: 0.9226, Precision: 0.6247, Recall: 0.1069, AUC ROC: 0.5506
# Iteration 498/5000 - Accuracy: 0.9226, Precision: 0.6244, Recall: 0.1068, AUC ROC: 0.5506
# Iteration 499/5000 - Accuracy: 0.9226, Precision: 0.6289, Recall: 0.1038, AUC ROC: 0.5492
# Iteration 500/5000 - Accuracy: 0.9226, Precision: 0.6254, Recall: 0.1056, AUC ROC: 0.5500
# Iteration 501/5000 - Accuracy: 0.9226, Precision: 0.6275, Recall: 0.1049, AUC ROC: 0.5497
# Iteration 502/5000 - Accuracy: 0.9226, Precision: 0.6289, Recall: 0.1030, AUC ROC: 0.5488
# Iteration 503/5000 - Accuracy: 0.9225, Precision: 0.6241, Recall: 0.1051, AUC ROC: 0.5498
# Iteration 504/5000 - Accuracy: 0.9226, Precision: 0.6251, Recall: 0.1071, AUC ROC: 0.5507
# Iteration 505/5000 - Accuracy: 0.9225, Precision: 0.6236, Recall: 0.1061, AUC ROC: 0.5502
# Iteration 506/5000 - Accuracy: 0.9227, Precision: 0.6295, Recall: 0.1073, AUC ROC: 0.5509
# Iteration 507/5000 - Accuracy: 0.9226, Precision: 0.6266, Recall: 0.1058, AUC ROC: 0.5501
# Iteration 508/5000 - Accuracy: 0.9225, Precision: 0.6251, Recall: 0.1051, AUC ROC: 0.5498
# Iteration 509/5000 - Accuracy: 0.9226, Precision: 0.6248, Recall: 0.1078, AUC ROC: 0.5510
# Iteration 510/5000 - Accuracy: 0.9226, Precision: 0.6287, Recall: 0.1048, AUC ROC: 0.5497
# Iteration 511/5000 - Accuracy: 0.9226, Precision: 0.6270, Recall: 0.1044, AUC ROC: 0.5495
# Iteration 512/5000 - Accuracy: 0.9227, Precision: 0.6290, Recall: 0.1057, AUC ROC: 0.5501
# Iteration 513/5000 - Accuracy: 0.9226, Precision: 0.6283, Recall: 0.1039, AUC ROC: 0.5493
# Iteration 514/5000 - Accuracy: 0.9226, Precision: 0.6270, Recall: 0.1040, AUC ROC: 0.5493
# Iteration 515/5000 - Accuracy: 0.9225, Precision: 0.6230, Recall: 0.1061, AUC ROC: 0.5502
# Iteration 516/5000 - Accuracy: 0.9225, Precision: 0.6233, Recall: 0.1046, AUC ROC: 0.5495
# Iteration 517/5000 - Accuracy: 0.9227, Precision: 0.6311, Recall: 0.1052, AUC ROC: 0.5499
# Iteration 518/5000 - Accuracy: 0.9225, Precision: 0.6240, Recall: 0.1042, AUC ROC: 0.5493
# Iteration 519/5000 - Accuracy: 0.9226, Precision: 0.6256, Recall: 0.1060, AUC ROC: 0.5502
# Iteration 520/5000 - Accuracy: 0.9226, Precision: 0.6264, Recall: 0.1048, AUC ROC: 0.5497
# Iteration 521/5000 - Accuracy: 0.9226, Precision: 0.6329, Recall: 0.1022, AUC ROC: 0.5485
# Iteration 522/5000 - Accuracy: 0.9225, Precision: 0.6264, Recall: 0.1037, AUC ROC: 0.5491
# Iteration 523/5000 - Accuracy: 0.9226, Precision: 0.6282, Recall: 0.1041, AUC ROC: 0.5493
# Iteration 524/5000 - Accuracy: 0.9226, Precision: 0.6256, Recall: 0.1061, AUC ROC: 0.5503
# Iteration 525/5000 - Accuracy: 0.9225, Precision: 0.6248, Recall: 0.1053, AUC ROC: 0.5499
# Iteration 526/5000 - Accuracy: 0.9226, Precision: 0.6281, Recall: 0.1036, AUC ROC: 0.5491
# Iteration 527/5000 - Accuracy: 0.9226, Precision: 0.6286, Recall: 0.1037, AUC ROC: 0.5492
# Iteration 528/5000 - Accuracy: 0.9225, Precision: 0.6279, Recall: 0.1031, AUC ROC: 0.5488
# Iteration 529/5000 - Accuracy: 0.9225, Precision: 0.6273, Recall: 0.1031, AUC ROC: 0.5489
# Iteration 530/5000 - Accuracy: 0.9225, Precision: 0.6256, Recall: 0.1036, AUC ROC: 0.5491
# Iteration 531/5000 - Accuracy: 0.9225, Precision: 0.6258, Recall: 0.1041, AUC ROC: 0.5493
# Iteration 532/5000 - Accuracy: 0.9225, Precision: 0.6272, Recall: 0.1031, AUC ROC: 0.5488
# Iteration 533/5000 - Accuracy: 0.9226, Precision: 0.6275, Recall: 0.1057, AUC ROC: 0.5501
# Iteration 534/5000 - Accuracy: 0.9226, Precision: 0.6296, Recall: 0.1052, AUC ROC: 0.5499
# ...
# Iteration 4826/5000 - Accuracy: 0.9247, Precision: 0.6590, Recall: 0.1418, AUC ROC: 0.5677
# Iteration 4827/5000 - Accuracy: 0.9249, Precision: 0.6621, Recall: 0.1442, AUC ROC: 0.5689
# Iteration 4828/5000 - Accuracy: 0.9247, Precision: 0.6599, Recall: 0.1423, AUC ROC: 0.5679
# Iteration 4829/5000 - Accuracy: 0.9247, Precision: 0.6573, Recall: 0.1427, AUC ROC: 0.5681
# Iteration 4830/5000 - Accuracy: 0.9246, Precision: 0.6574, Recall: 0.1419, AUC ROC: 0.5677
# Iteration 4831/5000 - Accuracy: 0.9247, Precision: 0.6621, Recall: 0.1412, AUC ROC: 0.5674
# Iteration 4832/5000 - Accuracy: 0.9248, Precision: 0.6601, Recall: 0.1430, AUC ROC: 0.5683
# Iteration 4833/5000 - Accuracy: 0.9247, Precision: 0.6571, Recall: 0.1447, AUC ROC: 0.5690
# Iteration 4834/5000 - Accuracy: 0.9248, Precision: 0.6610, Recall: 0.1423, AUC ROC: 0.5679
# Iteration 4835/5000 - Accuracy: 0.9247, Precision: 0.6565, Recall: 0.1435, AUC ROC: 0.5685
# Iteration 4836/5000 - Accuracy: 0.9247, Precision: 0.6564, Recall: 0.1441, AUC ROC: 0.5687
# Iteration 4837/5000 - Accuracy: 0.9247, Precision: 0.6586, Recall: 0.1425, AUC ROC: 0.5680
# Iteration 4838/5000 - Accuracy: 0.9248, Precision: 0.6615, Recall: 0.1432, AUC ROC: 0.5684
# Iteration 4839/5000 - Accuracy: 0.9246, Precision: 0.6568, Recall: 0.1408, AUC ROC: 0.5672
# Iteration 4840/5000 - Accuracy: 0.9248, Precision: 0.6618, Recall: 0.1418, AUC ROC: 0.5677
# Iteration 4841/5000 - Accuracy: 0.9247, Precision: 0.6590, Recall: 0.1423, AUC ROC: 0.5679
# Iteration 4842/5000 - Accuracy: 0.9247, Precision: 0.6592, Recall: 0.1422, AUC ROC: 0.5678
# Iteration 4843/5000 - Accuracy: 0.9248, Precision: 0.6631, Recall: 0.1431, AUC ROC: 0.5683
# Iteration 4844/5000 - Accuracy: 0.9246, Precision: 0.6532, Recall: 0.1444, AUC ROC: 0.5688
# Iteration 4845/5000 - Accuracy: 0.9246, Precision: 0.6537, Recall: 0.1424, AUC ROC: 0.5679
# Iteration 4846/5000 - Accuracy: 0.9248, Precision: 0.6608, Recall: 0.1427, AUC ROC: 0.5681
# Iteration 4847/5000 - Accuracy: 0.9248, Precision: 0.6616, Recall: 0.1422, AUC ROC: 0.5679
# Iteration 4848/5000 - Accuracy: 0.9247, Precision: 0.6608, Recall: 0.1410, AUC ROC: 0.5673
# Iteration 4849/5000 - Accuracy: 0.9247, Precision: 0.6585, Recall: 0.1420, AUC ROC: 0.5678
# Iteration 4850/5000 - Accuracy: 0.9247, Precision: 0.6581, Recall: 0.1428, AUC ROC: 0.5681
# Iteration 4851/5000 - Accuracy: 0.9246, Precision: 0.6576, Recall: 0.1416, AUC ROC: 0.5676
# Iteration 4852/5000 - Accuracy: 0.9246, Precision: 0.6567, Recall: 0.1419, AUC ROC: 0.5677
# Iteration 4853/5000 - Accuracy: 0.9247, Precision: 0.6580, Recall: 0.1434, AUC ROC: 0.5684
# Iteration 4854/5000 - Accuracy: 0.9246, Precision: 0.6559, Recall: 0.1429, AUC ROC: 0.5682
# Iteration 4855/5000 - Accuracy: 0.9248, Precision: 0.6579, Recall: 0.1447, AUC ROC: 0.5690
# Iteration 4856/5000 - Accuracy: 0.9248, Precision: 0.6621, Recall: 0.1420, AUC ROC: 0.5678
# Iteration 4857/5000 - Accuracy: 0.9246, Precision: 0.6555, Recall: 0.1429, AUC ROC: 0.5681
# Iteration 4858/5000 - Accuracy: 0.9248, Precision: 0.6598, Recall: 0.1437, AUC ROC: 0.5686
# Iteration 4859/5000 - Accuracy: 0.9247, Precision: 0.6591, Recall: 0.1423, AUC ROC: 0.5679
# Iteration 4860/5000 - Accuracy: 0.9247, Precision: 0.6588, Recall: 0.1428, AUC ROC: 0.5681
# Iteration 4861/5000 - Accuracy: 0.9247, Precision: 0.6566, Recall: 0.1435, AUC ROC: 0.5684
# Iteration 4862/5000 - Accuracy: 0.9246, Precision: 0.6552, Recall: 0.1436, AUC ROC: 0.5685
# Iteration 4863/5000 - Accuracy: 0.9247, Precision: 0.6552, Recall: 0.1444, AUC ROC: 0.5689
# Iteration 4864/5000 - Accuracy: 0.9246, Precision: 0.6552, Recall: 0.1426, AUC ROC: 0.5680
# Iteration 4865/5000 - Accuracy: 0.9248, Precision: 0.6616, Recall: 0.1428, AUC ROC: 0.5682
# Iteration 4866/5000 - Accuracy: 0.9247, Precision: 0.6557, Recall: 0.1438, AUC ROC: 0.5686
# Iteration 4867/5000 - Accuracy: 0.9247, Precision: 0.6599, Recall: 0.1409, AUC ROC: 0.5673
# Iteration 4868/5000 - Accuracy: 0.9246, Precision: 0.6557, Recall: 0.1430, AUC ROC: 0.5682
# Iteration 4869/5000 - Accuracy: 0.9248, Precision: 0.6648, Recall: 0.1414, AUC ROC: 0.5675
# Iteration 4870/5000 - Accuracy: 0.9245, Precision: 0.6527, Recall: 0.1421, AUC ROC: 0.5677
# Iteration 4871/5000 - Accuracy: 0.9246, Precision: 0.6570, Recall: 0.1421, AUC ROC: 0.5678
# Iteration 4872/5000 - Accuracy: 0.9246, Precision: 0.6551, Recall: 0.1425, AUC ROC: 0.5680
# Iteration 4873/5000 - Accuracy: 0.9247, Precision: 0.6556, Recall: 0.1434, AUC ROC: 0.5684
# Iteration 4874/5000 - Accuracy: 0.9246, Precision: 0.6565, Recall: 0.1419, AUC ROC: 0.5677
# Iteration 4875/5000 - Accuracy: 0.9248, Precision: 0.6605, Recall: 0.1438, AUC ROC: 0.5686
# Iteration 4876/5000 - Accuracy: 0.9247, Precision: 0.6573, Recall: 0.1427, AUC ROC: 0.5681
# Iteration 4877/5000 - Accuracy: 0.9246, Precision: 0.6547, Recall: 0.1428, AUC ROC: 0.5681
# Iteration 4878/5000 - Accuracy: 0.9247, Precision: 0.6556, Recall: 0.1438, AUC ROC: 0.5686
# Iteration 4879/5000 - Accuracy: 0.9247, Precision: 0.6558, Recall: 0.1438, AUC ROC: 0.5686
# Iteration 4880/5000 - Accuracy: 0.9248, Precision: 0.6624, Recall: 0.1428, AUC ROC: 0.5682
# Iteration 4881/5000 - Accuracy: 0.9247, Precision: 0.6611, Recall: 0.1418, AUC ROC: 0.5677
# Iteration 4882/5000 - Accuracy: 0.9246, Precision: 0.6525, Recall: 0.1439, AUC ROC: 0.5686
# Iteration 4883/5000 - Accuracy: 0.9247, Precision: 0.6556, Recall: 0.1439, AUC ROC: 0.5686
# Iteration 4884/5000 - Accuracy: 0.9247, Precision: 0.6557, Recall: 0.1450, AUC ROC: 0.5692
# Iteration 4885/5000 - Accuracy: 0.9247, Precision: 0.6541, Recall: 0.1448, AUC ROC: 0.5690
# Iteration 4886/5000 - Accuracy: 0.9247, Precision: 0.6545, Recall: 0.1447, AUC ROC: 0.5690
# Iteration 4887/5000 - Accuracy: 0.9247, Precision: 0.6576, Recall: 0.1443, AUC ROC: 0.5689
# Iteration 4888/5000 - Accuracy: 0.9246, Precision: 0.6529, Recall: 0.1434, AUC ROC: 0.5684
# Iteration 4889/5000 - Accuracy: 0.9247, Precision: 0.6583, Recall: 0.1427, AUC ROC: 0.5681
# Iteration 4890/5000 - Accuracy: 0.9246, Precision: 0.6565, Recall: 0.1426, AUC ROC: 0.5680
# Iteration 4891/5000 - Accuracy: 0.9246, Precision: 0.6520, Recall: 0.1443, AUC ROC: 0.5687
# Iteration 4892/5000 - Accuracy: 0.9248, Precision: 0.6584, Recall: 0.1444, AUC ROC: 0.5689
# Iteration 4893/5000 - Accuracy: 0.9247, Precision: 0.6552, Recall: 0.1437, AUC ROC: 0.5685
# Iteration 4894/5000 - Accuracy: 0.9247, Precision: 0.6538, Recall: 0.1447, AUC ROC: 0.5690
# Iteration 4895/5000 - Accuracy: 0.9247, Precision: 0.6575, Recall: 0.1446, AUC ROC: 0.5690
# Iteration 4896/5000 - Accuracy: 0.9247, Precision: 0.6565, Recall: 0.1446, AUC ROC: 0.5690
# Iteration 4897/5000 - Accuracy: 0.9247, Precision: 0.6556, Recall: 0.1438, AUC ROC: 0.5686
# Iteration 4898/5000 - Accuracy: 0.9247, Precision: 0.6542, Recall: 0.1449, AUC ROC: 0.5691
# Iteration 4899/5000 - Accuracy: 0.9246, Precision: 0.6518, Recall: 0.1438, AUC ROC: 0.5685
# Iteration 4900/5000 - Accuracy: 0.9247, Precision: 0.6546, Recall: 0.1449, AUC ROC: 0.5691
# Iteration 4901/5000 - Accuracy: 0.9246, Precision: 0.6526, Recall: 0.1438, AUC ROC: 0.5685
# Iteration 4902/5000 - Accuracy: 0.9247, Precision: 0.6605, Recall: 0.1419, AUC ROC: 0.5677
# Iteration 4903/5000 - Accuracy: 0.9245, Precision: 0.6520, Recall: 0.1428, AUC ROC: 0.5681
# Iteration 4904/5000 - Accuracy: 0.9247, Precision: 0.6601, Recall: 0.1420, AUC ROC: 0.5678
# Iteration 4905/5000 - Accuracy: 0.9247, Precision: 0.6556, Recall: 0.1438, AUC ROC: 0.5686
# Iteration 4906/5000 - Accuracy: 0.9246, Precision: 0.6510, Recall: 0.1453, AUC ROC: 0.5692
# Iteration 4907/5000 - Accuracy: 0.9247, Precision: 0.6591, Recall: 0.1429, AUC ROC: 0.5682
# Iteration 4908/5000 - Accuracy: 0.9247, Precision: 0.6534, Recall: 0.1456, AUC ROC: 0.5694
# Iteration 4909/5000 - Accuracy: 0.9247, Precision: 0.6570, Recall: 0.1439, AUC ROC: 0.5687
# Iteration 4910/5000 - Accuracy: 0.9248, Precision: 0.6602, Recall: 0.1435, AUC ROC: 0.5685
# Iteration 4911/5000 - Accuracy: 0.9248, Precision: 0.6595, Recall: 0.1443, AUC ROC: 0.5689
# Iteration 4912/5000 - Accuracy: 0.9248, Precision: 0.6632, Recall: 0.1425, AUC ROC: 0.5681
# Iteration 4913/5000 - Accuracy: 0.9247, Precision: 0.6565, Recall: 0.1452, AUC ROC: 0.5693
# Iteration 4914/5000 - Accuracy: 0.9245, Precision: 0.6515, Recall: 0.1434, AUC ROC: 0.5683
# Iteration 4915/5000 - Accuracy: 0.9248, Precision: 0.6609, Recall: 0.1448, AUC ROC: 0.5691
# Iteration 4916/5000 - Accuracy: 0.9248, Precision: 0.6598, Recall: 0.1450, AUC ROC: 0.5692
# Iteration 4917/5000 - Accuracy: 0.9248, Precision: 0.6588, Recall: 0.1442, AUC ROC: 0.5688
# Iteration 4918/5000 - Accuracy: 0.9247, Precision: 0.6562, Recall: 0.1447, AUC ROC: 0.5690
# Iteration 4919/5000 - Accuracy: 0.9247, Precision: 0.6519, Recall: 0.1462, AUC ROC: 0.5697
# Iteration 4920/5000 - Accuracy: 0.9248, Precision: 0.6582, Recall: 0.1448, AUC ROC: 0.5691
# Iteration 4921/5000 - Accuracy: 0.9246, Precision: 0.6549, Recall: 0.1434, AUC ROC: 0.5684
# Iteration 4922/5000 - Accuracy: 0.9248, Precision: 0.6588, Recall: 0.1447, AUC ROC: 0.5690
# Iteration 4923/5000 - Accuracy: 0.9246, Precision: 0.6529, Recall: 0.1442, AUC ROC: 0.5687
# Iteration 4924/5000 - Accuracy: 0.9247, Precision: 0.6576, Recall: 0.1422, AUC ROC: 0.5678
# Iteration 4925/5000 - Accuracy: 0.9248, Precision: 0.6587, Recall: 0.1440, AUC ROC: 0.5687
# Iteration 4926/5000 - Accuracy: 0.9248, Precision: 0.6584, Recall: 0.1459, AUC ROC: 0.5696
# Iteration 4927/5000 - Accuracy: 0.9248, Precision: 0.6602, Recall: 0.1444, AUC ROC: 0.5689
# Iteration 4928/5000 - Accuracy: 0.9248, Precision: 0.6597, Recall: 0.1446, AUC ROC: 0.5690
# Iteration 4929/5000 - Accuracy: 0.9248, Precision: 0.6619, Recall: 0.1430, AUC ROC: 0.5683
# Iteration 4930/5000 - Accuracy: 0.9248, Precision: 0.6594, Recall: 0.1439, AUC ROC: 0.5687
# Iteration 4931/5000 - Accuracy: 0.9248, Precision: 0.6584, Recall: 0.1458, AUC ROC: 0.5696
# Iteration 4932/5000 - Accuracy: 0.9247, Precision: 0.6562, Recall: 0.1438, AUC ROC: 0.5686
# Iteration 4933/5000 - Accuracy: 0.9248, Precision: 0.6594, Recall: 0.1445, AUC ROC: 0.5690
# Iteration 4934/5000 - Accuracy: 0.9247, Precision: 0.6555, Recall: 0.1445, AUC ROC: 0.5689
# Iteration 4935/5000 - Accuracy: 0.9248, Precision: 0.6621, Recall: 0.1439, AUC ROC: 0.5687
# Iteration 4936/5000 - Accuracy: 0.9248, Precision: 0.6605, Recall: 0.1441, AUC ROC: 0.5688
# Iteration 4937/5000 - Accuracy: 0.9249, Precision: 0.6630, Recall: 0.1437, AUC ROC: 0.5686
# Iteration 4938/5000 - Accuracy: 0.9248, Precision: 0.6595, Recall: 0.1451, AUC ROC: 0.5692
# Iteration 4939/5000 - Accuracy: 0.9248, Precision: 0.6602, Recall: 0.1429, AUC ROC: 0.5682
# Iteration 4940/5000 - Accuracy: 0.9247, Precision: 0.6566, Recall: 0.1437, AUC ROC: 0.5685
# Iteration 4941/5000 - Accuracy: 0.9248, Precision: 0.6598, Recall: 0.1446, AUC ROC: 0.5690
# Iteration 4942/5000 - Accuracy: 0.9248, Precision: 0.6604, Recall: 0.1441, AUC ROC: 0.5688
# Iteration 4943/5000 - Accuracy: 0.9247, Precision: 0.6580, Recall: 0.1434, AUC ROC: 0.5684
# Iteration 4944/5000 - Accuracy: 0.9247, Precision: 0.6591, Recall: 0.1430, AUC ROC: 0.5682
# Iteration 4945/5000 - Accuracy: 0.9247, Precision: 0.6571, Recall: 0.1448, AUC ROC: 0.5691
# Iteration 4946/5000 - Accuracy: 0.9247, Precision: 0.6599, Recall: 0.1426, AUC ROC: 0.5681
# Iteration 4947/5000 - Accuracy: 0.9245, Precision: 0.6543, Recall: 0.1416, AUC ROC: 0.5675
# Iteration 4948/5000 - Accuracy: 0.9247, Precision: 0.6586, Recall: 0.1438, AUC ROC: 0.5686
# Iteration 4949/5000 - Accuracy: 0.9248, Precision: 0.6587, Recall: 0.1441, AUC ROC: 0.5688
# Iteration 4950/5000 - Accuracy: 0.9248, Precision: 0.6621, Recall: 0.1437, AUC ROC: 0.5686
# Iteration 4951/5000 - Accuracy: 0.9248, Precision: 0.6599, Recall: 0.1436, AUC ROC: 0.5685
# Iteration 4952/5000 - Accuracy: 0.9247, Precision: 0.6538, Recall: 0.1451, AUC ROC: 0.5692
# Iteration 4953/5000 - Accuracy: 0.9247, Precision: 0.6567, Recall: 0.1442, AUC ROC: 0.5688
# Iteration 4954/5000 - Accuracy: 0.9248, Precision: 0.6610, Recall: 0.1440, AUC ROC: 0.5687
# Iteration 4955/5000 - Accuracy: 0.9247, Precision: 0.6549, Recall: 0.1445, AUC ROC: 0.5689
# Iteration 4956/5000 - Accuracy: 0.9247, Precision: 0.6569, Recall: 0.1436, AUC ROC: 0.5685
# Iteration 4957/5000 - Accuracy: 0.9248, Precision: 0.6598, Recall: 0.1444, AUC ROC: 0.5689
# Iteration 4958/5000 - Accuracy: 0.9247, Precision: 0.6568, Recall: 0.1438, AUC ROC: 0.5686
# Iteration 4959/5000 - Accuracy: 0.9247, Precision: 0.6585, Recall: 0.1426, AUC ROC: 0.5680
# Iteration 4960/5000 - Accuracy: 0.9247, Precision: 0.6561, Recall: 0.1436, AUC ROC: 0.5685
# Iteration 4961/5000 - Accuracy: 0.9246, Precision: 0.6519, Recall: 0.1446, AUC ROC: 0.5689
# Iteration 4962/5000 - Accuracy: 0.9247, Precision: 0.6609, Recall: 0.1421, AUC ROC: 0.5678
# Iteration 4963/5000 - Accuracy: 0.9247, Precision: 0.6573, Recall: 0.1441, AUC ROC: 0.5688
# Iteration 4964/5000 - Accuracy: 0.9246, Precision: 0.6549, Recall: 0.1437, AUC ROC: 0.5685
# Iteration 4965/5000 - Accuracy: 0.9248, Precision: 0.6598, Recall: 0.1434, AUC ROC: 0.5685
# Iteration 4966/5000 - Accuracy: 0.9248, Precision: 0.6589, Recall: 0.1438, AUC ROC: 0.5686
# Iteration 4967/5000 - Accuracy: 0.9246, Precision: 0.6566, Recall: 0.1424, AUC ROC: 0.5679
# Iteration 4968/5000 - Accuracy: 0.9248, Precision: 0.6600, Recall: 0.1430, AUC ROC: 0.5682
# Iteration 4969/5000 - Accuracy: 0.9246, Precision: 0.6536, Recall: 0.1440, AUC ROC: 0.5686
# Iteration 4970/5000 - Accuracy: 0.9247, Precision: 0.6580, Recall: 0.1439, AUC ROC: 0.5687
# Iteration 4971/5000 - Accuracy: 0.9247, Precision: 0.6557, Recall: 0.1436, AUC ROC: 0.5685
# Iteration 4972/5000 - Accuracy: 0.9247, Precision: 0.6575, Recall: 0.1430, AUC ROC: 0.5682
# Iteration 4973/5000 - Accuracy: 0.9248, Precision: 0.6600, Recall: 0.1444, AUC ROC: 0.5689
# Iteration 4974/5000 - Accuracy: 0.9247, Precision: 0.6555, Recall: 0.1435, AUC ROC: 0.5684
# Iteration 4975/5000 - Accuracy: 0.9246, Precision: 0.6518, Recall: 0.1445, AUC ROC: 0.5688
# Iteration 4976/5000 - Accuracy: 0.9247, Precision: 0.6553, Recall: 0.1436, AUC ROC: 0.5685
# Iteration 4977/5000 - Accuracy: 0.9246, Precision: 0.6498, Recall: 0.1450, AUC ROC: 0.5691
# Iteration 4978/5000 - Accuracy: 0.9247, Precision: 0.6570, Recall: 0.1434, AUC ROC: 0.5684
# Iteration 4979/5000 - Accuracy: 0.9247, Precision: 0.6589, Recall: 0.1427, AUC ROC: 0.5681
# Iteration 4980/5000 - Accuracy: 0.9247, Precision: 0.6609, Recall: 0.1413, AUC ROC: 0.5674
# Iteration 4981/5000 - Accuracy: 0.9248, Precision: 0.6588, Recall: 0.1447, AUC ROC: 0.5690
# Iteration 4982/5000 - Accuracy: 0.9247, Precision: 0.6590, Recall: 0.1427, AUC ROC: 0.5681
# Iteration 4983/5000 - Accuracy: 0.9248, Precision: 0.6607, Recall: 0.1429, AUC ROC: 0.5682
# Iteration 4984/5000 - Accuracy: 0.9246, Precision: 0.6522, Recall: 0.1445, AUC ROC: 0.5688
# Iteration 4985/5000 - Accuracy: 0.9248, Precision: 0.6613, Recall: 0.1426, AUC ROC: 0.5681
# Iteration 4986/5000 - Accuracy: 0.9247, Precision: 0.6575, Recall: 0.1426, AUC ROC: 0.5680
# Iteration 4987/5000 - Accuracy: 0.9247, Precision: 0.6549, Recall: 0.1440, AUC ROC: 0.5687
# Iteration 4988/5000 - Accuracy: 0.9247, Precision: 0.6574, Recall: 0.1441, AUC ROC: 0.5687
# Iteration 4989/5000 - Accuracy: 0.9246, Precision: 0.6548, Recall: 0.1435, AUC ROC: 0.5684
# Iteration 4990/5000 - Accuracy: 0.9246, Precision: 0.6540, Recall: 0.1425, AUC ROC: 0.5679
# Iteration 4991/5000 - Accuracy: 0.9246, Precision: 0.6545, Recall: 0.1433, AUC ROC: 0.5683
# Iteration 4992/5000 - Accuracy: 0.9247, Precision: 0.6583, Recall: 0.1419, AUC ROC: 0.5677
# Iteration 4993/5000 - Accuracy: 0.9246, Precision: 0.6555, Recall: 0.1417, AUC ROC: 0.5676
# Iteration 4994/5000 - Accuracy: 0.9245, Precision: 0.6481, Recall: 0.1438, AUC ROC: 0.5685
# Iteration 4995/5000 - Accuracy: 0.9247, Precision: 0.6590, Recall: 0.1416, AUC ROC: 0.5676
# Iteration 4996/5000 - Accuracy: 0.9247, Precision: 0.6590, Recall: 0.1422, AUC ROC: 0.5679
# Iteration 4997/5000 - Accuracy: 0.9247, Precision: 0.6565, Recall: 0.1439, AUC ROC: 0.5686
# Iteration 4998/5000 - Accuracy: 0.9247, Precision: 0.6597, Recall: 0.1421, AUC ROC: 0.5678
# Iteration 4999/5000 - Accuracy: 0.9246, Precision: 0.6556, Recall: 0.1429, AUC ROC: 0.5681
# Iteration 5000/5000 - Accuracy: 0.9247, Precision: 0.6590, Recall: 0.1431, AUC ROC: 0.5683

# %% [markdown]
# # Model Validation

# %%
# Plot the training progress for accuracy
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, max_iterations + 1), accuracy_scores)
plt.xlabel('Iterations')
plt.ylabel('Accuracy')
plt.title('Training Progress (Accuracy)')

# Plot the training progress for AUC ROC
plt.subplot(1, 2, 2)
plt.plot(range(1, max_iterations + 1), roc_auc_scores)
plt.xlabel('Iterations')
plt.ylabel('AUC ROC')
plt.title('Training Progress (AUC ROC)')

# Plot the training progress for accuracy
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, max_iterations + 1), recall_scores)
plt.xlabel('Iterations')
plt.ylabel('Recall')
plt.title('Training Progress (Recall)')

# Plot the training progress for AUC ROC
plt.subplot(1, 2, 2)
plt.plot(range(1, max_iterations + 1), precision_scores)
plt.xlabel('Iterations')
plt.ylabel('Precision')
plt.title('Training Progress (Precision)')

plt.tight_layout()
plt.show()

# Display the final evaluation metrics and confusion matrix
final_iteration = max_iterations - 1
print('\nFinal Evaluation Metrics with RFE:')
print(f'Accuracy: {accuracy_scores[final_iteration]:.4f}')
print(f'Precision: {precision_scores[final_iteration]:.4f}')
print(f'Recall: {recall_scores[final_iteration]:.4f}')
print(f'AUC ROC: {roc_auc_scores[final_iteration]:.4f}')
print('\nConfusion Matrix:')
print(confusion_matrices[final_iteration])
# Out:
# Final Evaluation Metrics with RFE:
# Accuracy: 0.9247
# Precision: 0.6590
# Recall: 0.1431
# AUC ROC: 0.5683
#
# Confusion Matrix:
# [[225627   1479]
#  [ 17119   2858]]

# %% [markdown]
# # Saving the Model

# %%
# Save the trained MLP model with RFE-selected features
with open('mlp_model_rfe.pkl', 'wb') as file:
    pickle.dump(mlp_model_rfe, file)
